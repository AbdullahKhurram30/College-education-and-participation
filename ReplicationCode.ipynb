# %%
#######################
#   John Henderson    #
#    UC-Berkeley      #            
#       &             #
#   Sara Chatfield    #
#    UC-Berkeley      #       
#                     # 
#    Who Matches:     #
#   Replication Code  #
#                     #
#   Released          #
#     Version 1.0     #
#                     #
#   Nov 17, 2010      #
#######################


# USAGE
#########################################  
# This is replication code for Henderson, John, and Sara Chatfield. 2011. "Who Matches? Propensity Scores and Bias in the Causal Effects
# of Education on Participation," Journal of Politics.  The software, code, and data may be used, distributed, and modified freely 
# with proper attribution to both Henderson and Chatfield (2011) and Kam and Palmer (2008). 


# DESCRPITION
######################################### 
# This is the code for the replication of Kam and Palmers (2008) propensity score matching analysis. This code is 
# slightly modified and expanded from the original code provided by Kam and Palmer (2008), and correspondes to their article 
# 'Reconsidering the Effects of Education on Political Participation'.  
# 
# In addition to the authors propensity score, included below are MatchBalance statistics, placbeo tests, and alternative 
# matching models.
#  
# Tables 1 - 4 in the paper "Who Matches?", are produced below.  These are the models 'mout_r1', 'mout_r1D', 'mout_r3', 
# and 'mout_r3D'.  Balance statistisc are found in 'matbal_r1' and 'matbal_r3'.
#
# Additionally, diagnostic statistics are also estimated below.  These includes the moments of the Kam and Palmer (2008) 
# propesity score, as well as its degree of overlap, among other things.
 

library(MASS)
library(Matching)
 
source('funcs.R')   
load("WhoMatches.Rdata")

# %%
#source('objects.R')
attach(data_rep)
attach(factors)

# %%
# KP Pscore
#  Note the the Z suffix indicates that the covariate is factorized following Kam and Palmer (2008)

model=formula(college ~ yPubAffZ + yNewspaperZ + yRadioZ + yMagazineZ + yFamTalkZ + yFrTalkZ + yAdultTalkZ + ySPIDZ + yGovtOpinionZ + yGovtCrookZ + yGovtWasteZ + yTrGovtZ + yGovtSmartZ + yGovt4AllZ + yLifeWishZ + yGLuckZ + yFPlansZ + yWinArgZ + yStrOpinionZ + 
	yMChangeZ + yTrOthersZ + yOthHelpZ + yOthFairZ + yKnowledgeZ + yNextSchZ + yGPAZ + ySchOfficerZ + ySchPublishZ + yHobbyZ + ySchClubZ + yOccClubZ + yNeighClubZ + yRelClubZ + yYouthOrgZ + yClubLevZ + yPhoneZ + yGenZ + yRaceZ + pNewspaperZ + pRadioZ + pTVZ + 
	pMagazineZ + pLifeWishZ + pGLuckZ + pFPlansZ + pWinArgZ + pStrOpinionZ + pMChangeZ + pTrOthersZ + pOthHelpZ + pOthFairZ + pSPIDZ + pVoteZ + pPersuadeZ + pRallyZ + pOthActZ + pPolClubZ + pButtonZ + pMoneyZ + pGovtOpinionZ + pGovtCrookZ + pGovtWasteZ + pTrGovtZ + 
	pGovtSmartZ + pGovt4AllZ + pEmployZ + pEducHHZ + pChurchOrgZ + pFratOrgZ + pProOrgZ + pCivicOrgZ + pCLOrgZ + pNeighClubZ + pSportClubZ + pInfClubZ + pFarmGrZ + pWomenClubZ + pClubLevZ + pHHIncZ + pOwnHomeZ + pKnowledgeZ)
pscore=glm(model,family=binomial(link=logit))
etahat=pscore$fitted.values


# Propensity Score Matching
#  Note that 'out' is a n x 355 matrix, which is produced by dichotomizing 109 (86) covariates.  

#1973: 1 to 3

mout_r1 = Match(Y = yppnscal, Tr = college, X = etahat, estimand="ATT", M = 3) 
summary(mout_r1)

matbal_r1 = MatchBalance(college ~ etahat + yGPA + yGen + yBlack + yRep+ yKnowledge + yNextSch + pVote + pPersuade + pParticipate2 + pEmploy + pEducHH + pEducW + pHHInc + pOwnHome + pRep  + pKnowledge, match.out = mout_r1,nboots=1000)
matbal_all1=MatchBalance(college ~ out, match.out = mout_r1)
mb1=percent.bal(matbal_all1)
mb1[[1]] # 0.4084507 :: 0.2535211

# Outliers Dropped: 723, 676, 1061, 337, 595

mout_r1D = Match(Y= yppnscal[-c(723,676,1061,337,595)], Tr = college[-c(723,676,1061,337,595)], X = etahat[-c(723,676,1061,337,595)], estimand="ATT", M = 3) 
summary(mout_r1D)


#1973: 1 to 1

mout_r2 = Match(Y=yppnscal, Tr=college, X=etahat, estimand="ATT", M=1)   
summary(mout_r2)

matbal_r2 = MatchBalance(college ~ etahat + yGPA + yGen + yBlack + yRep+ yKnowledge + yNextSch + pVote + pPersuade + pParticipate2 + pEmploy + pEducHH + pEducW + pHHInc + pOwnHome + pRep  + pKnowledge, match.out = mout_r2,nboots=1000)
matbal_all2=MatchBalance(college ~ out, match.out = mout_r2)
mb2=percent.bal(matbal_all2)
mb2[[1]] # 0.4084507 :: 0.2366197

# Outliers Dropped: 723, 676, 1061, 337, 595

mout_r2D = Match(Y=yppnscal[-c(723,676,1061,337,595)], Tr=college[-c(723,676,1061,337,595)], X=etahat[-c(723,676,1061,337,595)], estimand="ATT", M=1)   
summary(mout_r2D)


#1982: 1 to 3

mout_r3 = Match(Y = y1982yppnscal[!is.na(y1982yppnscal)], Tr = college[!is.na(y1982yppnscal)], X = etahat[!is.na(y1982yppnscal)], estimand="ATT", M = 3) 
summary(mout_r3)

matbal_r3 = MatchBalance(college ~ etahat + yGPA + yGen + yBlack + yRep+ yKnowledge + yNextSch + pVote + pPersuade + pParticipate2 + pEmploy + pEducHH + pEducW + pHHInc + pOwnHome + pRep  + pKnowledge, match.out = mout_r3,nboots=1000)
matbal_all3=MatchBalance(college ~ out, match.out = mout_r3)
mb3=percent.bal(matbal_all3)
mb3[[1]] # 0.4084507 :: 0.2394366

# Outliers Dropped [after dropping missings in 1982 and re-indexing]:  613, 572, 897, 337, 507 

mout_r3D = Match(Y = y1982yppnscal[!is.na(y1982yppnscal)][-c(572,897,296,613,507)], Tr = college[!is.na(y1982yppnscal)][-c(572,897,296,613,507)], X = etahat[!is.na(y1982yppnscal)][-c(572,897,296,613,507)], estimand="ATT", M = 3) 
summary(mout_r3D)


#1982: 1 to 1

mout_r4 = Match(Y = y1982yppnscal[!is.na(y1982yppnscal)], Tr = college[!is.na(y1982yppnscal)], X = etahat[!is.na(y1982yppnscal)], estimand="ATT", M = 1) 
summary(mout_r4)

matbal_r4 = MatchBalance(college ~ etahat + yGPA + yGen + yBlack + yRep+ yKnowledge + yNextSch + pVote + pPersuade + pParticipate2 + pEmploy + pEducHH + pEducW + pHHInc + pOwnHome + pRep  + pKnowledge, match.out = mout_r4,nboots=1000)
matbal_all4=MatchBalance(college ~ out, match.out = mout_r4)
mb4=percent.bal(matbal_all4)
mb4[[1]] # 0.4084507 :: 0.2732394

# Outliers Dropped [after dropping missings in 1982 and re-indexing]:  613, 572, 897, 337, 507 

mout_r4D = Match(Y = y1982yppnscal[!is.na(y1982yppnscal)][-c(572,897,296,613,507)], Tr = college[!is.na(y1982yppnscal)][-c(572,897,296,613,507)], X = etahat[!is.na(y1982yppnscal)][-c(572,897,296,613,507)], estimand="ATT", M = 1) 
summary(mout_r4D)


# Pscore Stats/Diagnostics

# Control Outlers Index (1973): 723, 676, 1061, 337, 595
# Control Outlers Index (1982): 613, 572, 897, 337, 507 

# Moments 

caliper = .25
mean(etahat)                                                                # 0.6403509
mean(etahat[college==1])                                                    # 0.8338374
mean(etahat[college==0])                                                    # 0.2958504
sd(etahat)                                                                  # 0.3512628
sd(etahat)*caliper                                                          # 0.0878157

# Max/Min/95th Percentile

sort(etahat[college==0])[round(.95*length(etahat[college==0]))+1]           # 0.8280431 
sort(etahat[college==1])[round(.95*length(etahat[college==1]))+1]           # 0.9998174 
max(etahat[college==1])                                                     # 0.9999998
min(etahat[college==1])                                                     # 0.02330369
max(etahat[college==0])                                                     # 0.9889442
min(etahat[college==0])                                                     # 1.196065e-10

# No Overlap at the Endpoints

length(which(etahat[college==0]>.9))/length(etahat[college==0])             # 0.03104213
length(which(etahat[college==0]>.95))/length(etahat[college==0])            # 0.01108647
length(which(etahat[college==1]>.9))/length(etahat[college==0])             # 0.5728518
length(which(etahat[college==1]>.95))/length(etahat[college==0])            # 0.4458281

length(which(etahat[college==1] > max(etahat[college==0])))/nrow(data_rep)  # 0.1714514
length(which(etahat[college==0] < min(etahat[college==1])))/nrow(data_rep)  # 0.05582137

# Outliers Index (1973)

which(etahat[college==0]>.95) 
sort(etahat[c(337,595,676,723,1061)])
index_r1=cbind(mout_r1$index.treated,mout_r1$index.control)

# Corresponding Matches of Outliers to College Attenders (Treatment)

length(which(index_r1[,2]==337))                                            # 60
length(which(index_r1[,2]==595))                                            # 58
length(which(index_r1[,2]==676))                                            # 316
length(which(index_r1[,2]==723))                                            # 287
length(which(index_r1[,2]==1061))                                           # 335

length(which(index_r1[,2]==337))/nrow(index_r1)                             # 0.02451982
length(which(index_r1[,2]==595))/nrow(index_r1)                             # 0.02370249
length(which(index_r1[,2]==676))/nrow(index_r1)                             # 0.1291377
length(which(index_r1[,2]==723))/nrow(index_r1)                             # 0.1172865
length(which(index_r1[,2]==1061))/nrow(index_r1)                            # 0.1369023

(length(which(index_r1[,2]==337))+length(which(index_r1[,2]==595))+length(which(index_r1[,2]==676))+length(which(index_r1[,2]==723))+length(which(index_r1[,2]==1061)))/nrow(index_r1) # 0.4315488

# Participatory Outliers: 1973 & 1982

mean(yppnscal[college==1 & etahat>.95])                                     # 3.26257
mean(yppnscal[college==0 & etahat>.95])                                     # 4
mean(yppnscal[college==1])                                                  # 2.793275
mean(yppnscal[college==0])                                                  # 1.427938

mean(data_rep$y1982yppnscal[college==1 & etahat>.95],na.rm=T)               # 3.319355
mean(data_rep$y1982yppnscal[college==0 & etahat>.95],na.rm=T)               # 4.4
mean(data_rep$y1982yppnscal[college==1],na.rm=T)                            # 3.041543
mean(data_rep$y1982yppnscal[college==0],na.rm=T)                            # 1.976064



# END
# Out:
# Estimate...  0.022748
# AI SE......  0.46899
# T-stat.....  0.048504
# p.val......  0.96131
#
# Original number of observations..............  1254
# Original number of treated obs...............  803
# Matched number of observations...............  803
# Matched number of observations  (unweighted).  2447
#
#
# ***** (V1) etahat *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.83384 	 	    0.83384
# mean control..........    0.29585 	 	    0.82957
# std mean diff.........     248.21 	 	     1.9674
#
# mean raw eQQ diff.....    0.53703 	 	  0.0058215
# med  raw eQQ diff.....    0.60628 	 	  0.0037115
# max  raw eQQ diff.....    0.74688 	 	   0.017799
#
# mean eCDF diff........     0.4235 	 	   0.039755
# med  eCDF diff........    0.46206 	 	   0.003678
# max  eCDF diff........    0.69313 	 	    0.26359
#
# var ratio (Tr/Co).....    0.63414 	 	     1.0284
# T-test p-value........ < 2.22e-16 	 	 < 2.22e-16
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... < 2.22e-16 	 	 < 2.22e-16
# KS Statistic..........    0.69313 	 	    0.26359
#
#
# ***** (V2) yGPA *****
#                        Before Matching 	 	 After Matching
# mean treatment........      2.274 	 	      2.274
# mean control..........     2.6231 	 	     2.5336
# std mean diff.........    -53.323 	 	    -39.662
#
# mean raw eQQ diff.....    0.35033 	 	    0.26522
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.069817 	 	   0.066306
# med  eCDF diff........   0.049631 	 	   0.013077
# max  eCDF diff........    0.23282 	 	    0.23907
#
# var ratio (Tr/Co).....    0.91008 	 	     1.0065
# T-test p-value........ < 2.22e-16 	 	 1.1546e-14
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... 5.0626e-14 	 	 < 2.22e-16
# KS Statistic..........    0.23282 	 	    0.23907
#
#
# ***** (V3) yGen *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.54795 	 	    0.54795
# mean control..........    0.43237 	 	    0.65787
# std mean diff.........     23.207 	 	    -22.072
#
# mean raw eQQ diff.....     0.1153 	 	    0.10503
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.057786 	 	   0.052513
# med  eCDF diff........   0.057786 	 	   0.052513
# max  eCDF diff........    0.11557 	 	    0.10503
#
# var ratio (Tr/Co).....     1.0083 	 	     1.1005
# T-test p-value........ 8.2568e-05 	 	 5.7513e-06
#
#
# ***** (V4) yBlack *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.064757 	 	   0.064757
# mean control..........   0.088692 	 	   0.077148
# std mean diff.........    -9.7196 	 	    -5.0319
#
# mean raw eQQ diff.....    0.02439 	 	   0.011851
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.011967 	 	  0.0059256
# med  eCDF diff........   0.011967 	 	  0.0059256
# max  eCDF diff........   0.023935 	 	   0.011851
#
# var ratio (Tr/Co).....    0.74858 	 	    0.85066
# T-test p-value........    0.13439 	 	    0.32638
#
#
# ***** (V5) yRep *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.34371 	 	    0.34371
# mean control..........     0.2439 	 	    0.23157
# std mean diff.........     21.002 	 	     23.597
#
# mean raw eQQ diff.....   0.099778 	 	    0.10993
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.049904 	 	   0.054965
# med  eCDF diff........   0.049904 	 	   0.054965
# max  eCDF diff........   0.099809 	 	    0.10993
#
# var ratio (Tr/Co).....      1.222 	 	     1.2677
# T-test p-value........ 0.00015535 	 	 6.9967e-07
#
#
# ***** (V6) yKnowledge *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.67518 	 	    0.67518
# mean control..........    0.46341 	 	    0.64261
# std mean diff.........     93.001 	 	     14.304
#
# mean raw eQQ diff.....    0.21101 	 	   0.036916
# med  raw eQQ diff.....    0.16667 	 	          0
# max  raw eQQ diff.....    0.33333 	 	    0.16667
#
# mean eCDF diff........    0.18151 	 	   0.031642
# med  eCDF diff........    0.13808 	 	   0.011851
# max  eCDF diff........    0.36777 	 	    0.11688
#
# var ratio (Tr/Co).....    0.94027 	 	     1.2301
# T-test p-value........ < 2.22e-16 	 	 0.00084985
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... < 2.22e-16 	 	 6.1062e-15
# KS Statistic..........    0.36777 	 	    0.11688
#
#
# ***** (V7) yNextSch *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.95766 	 	    0.95766
# mean control..........    0.64523 	 	    0.94768
# std mean diff.........     155.06 	 	     4.9547
#
# mean raw eQQ diff.....    0.31042 	 	  0.0098079
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.15621 	 	   0.004904
# med  eCDF diff........    0.15621 	 	   0.004904
# max  eCDF diff........    0.31243 	 	  0.0098079
#
# var ratio (Tr/Co).....    0.17697 	 	    0.81773
# T-test p-value........ < 2.22e-16 	 	    0.30554
#
#
# ***** (V8) pVote *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.88667 	 	    0.88667
# mean control..........    0.75166 	 	    0.90809
# std mean diff.........     42.565 	 	     -6.753
#
# mean raw eQQ diff.....    0.13304 	 	   0.020433
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.067506 	 	   0.010217
# med  eCDF diff........   0.067506 	 	   0.010217
# max  eCDF diff........    0.13501 	 	   0.020433
#
# var ratio (Tr/Co).....    0.53778 	 	      1.204
# T-test p-value........ 9.3798e-09 	 	    0.14753
#
#
# ***** (V9) pPersuade *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.45828 	 	    0.45828
# mean control..........    0.26386 	 	     0.4633
# std mean diff.........     38.996 	 	    -1.0075
#
# mean raw eQQ diff.....     0.1929 	 	  0.0057213
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.097212 	 	  0.0028606
# med  eCDF diff........   0.097212 	 	  0.0028606
# max  eCDF diff........    0.19442 	 	  0.0057213
#
# var ratio (Tr/Co).....     1.2769 	 	    0.99842
# T-test p-value........ 1.7437e-12 	 	    0.83342
#
#
# ***** (V10) pParticipate2 *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.23387 	 	    0.23387
# mean control..........    0.12239 	 	    0.19256
# std mean diff.........     38.387 	 	     14.225
#
# mean raw eQQ diff.....    0.11086 	 	   0.040621
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....        0.4 	 	        0.4
#
# mean eCDF diff........   0.092899 	 	   0.033851
# med  eCDF diff........   0.080506 	 	   0.015325
# max  eCDF diff........    0.19087 	 	   0.089089
#
# var ratio (Tr/Co).....     1.6441 	 	     1.4924
# T-test p-value........ 9.8588e-14 	 	  0.0015134
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... 1.4534e-09 	 	 7.3528e-09
# KS Statistic..........    0.19087 	 	   0.089089
#
#
# ***** (V11) pEmploy *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.69614 	 	    0.69614
# mean control..........    0.61197 	 	    0.65511
# std mean diff.........     18.289 	 	     8.9163
#
# mean raw eQQ diff.....   0.084257 	 	    0.03964
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.042083 	 	    0.01982
# med  eCDF diff........   0.042083 	 	    0.01982
# max  eCDF diff........   0.084166 	 	    0.03964
#
# var ratio (Tr/Co).....    0.88993 	 	    0.93621
# T-test p-value........  0.0028505 	 	   0.079485
#
#
# ***** (V12) pEducHH *****
#                        Before Matching 	 	 After Matching
# mean treatment........     3.3238 	 	     3.3238
# mean control..........     2.1685 	 	     2.8938
# std mean diff.........       78.8 	 	     29.332
#
# mean raw eQQ diff.....      1.153 	 	    0.46955
# med  raw eQQ diff.....          1 	 	          0
# max  raw eQQ diff.....          2 	 	          2
#
# mean eCDF diff........    0.19255 	 	   0.078259
# med  eCDF diff........     0.1919 	 	   0.079689
# max  eCDF diff........    0.35896 	 	     0.1651
#
# var ratio (Tr/Co).....     1.7174 	 	     1.6297
# T-test p-value........ < 2.22e-16 	 	 9.7167e-13
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... < 2.22e-16 	 	 < 2.22e-16
# KS Statistic..........    0.35896 	 	     0.1651
#
#
# ***** (V13) pEducW *****
#                        Before Matching 	 	 After Matching
# mean treatment........     3.1071 	 	     3.1071
# mean control..........     2.2993 	 	     2.2377
# std mean diff.........     66.627 	 	     71.709
#
# mean raw eQQ diff.....     0.8071 	 	    0.85615
# med  raw eQQ diff.....          1 	 	          1
# max  raw eQQ diff.....          2 	 	          2
#
# mean eCDF diff........    0.13463 	 	    0.14269
# med  eCDF diff........    0.12795 	 	    0.12526
# max  eCDF diff........    0.28585 	 	      0.302
#
# var ratio (Tr/Co).....     1.4055 	 	    0.95783
# T-test p-value........ < 2.22e-16 	 	 < 2.22e-16
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... < 2.22e-16 	 	 < 2.22e-16
# KS Statistic..........    0.28585 	 	      0.302
#
#
# ***** (V14) pHHInc *****
#                        Before Matching 	 	 After Matching
# mean treatment........     7.2864 	 	     7.2864
# mean control..........     5.9047 	 	     7.3693
# std mean diff.........     64.452 	 	    -3.8677
#
# mean raw eQQ diff.....     1.3747 	 	     0.5096
# med  raw eQQ diff.....          1 	 	          1
# max  raw eQQ diff.....          2 	 	          1
#
# mean eCDF diff........    0.13818 	 	    0.05096
# med  eCDF diff........    0.14333 	 	    0.03351
# max  eCDF diff........    0.26128 	 	    0.11892
#
# var ratio (Tr/Co).....     0.9501 	 	     1.5283
# T-test p-value........ < 2.22e-16 	 	     0.3419
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... < 2.22e-16 	 	 1.8874e-15
# KS Statistic..........    0.26128 	 	    0.11892
#
#
# ***** (V15) pOwnHome *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.84433 	 	    0.84433
# mean control..........    0.74279 	 	    0.90924
# std mean diff.........     27.991 	 	    -17.891
#
# mean raw eQQ diff.....   0.099778 	 	    0.06416
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.05077 	 	    0.03208
# med  eCDF diff........    0.05077 	 	    0.03208
# max  eCDF diff........    0.10154 	 	    0.06416
#
# var ratio (Tr/Co).....    0.68728 	 	     1.5926
# T-test p-value........ 3.1568e-05 	 	 5.4318e-05
#
#
# ***** (V16) pRep *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.36737 	 	    0.36737
# mean control..........    0.26386 	 	    0.27306
# std mean diff.........     21.459 	 	     19.551
#
# mean raw eQQ diff.....      0.102 	 	   0.091949
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.051757 	 	   0.045975
# med  eCDF diff........   0.051757 	 	   0.045975
# max  eCDF diff........    0.10351 	 	   0.091949
#
# var ratio (Tr/Co).....     1.1954 	 	     1.1708
# T-test p-value........ 0.00012362 	 	 5.7403e-05
#
#
# ***** (V17) pKnowledge *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.67206 	 	    0.67206
# mean control..........    0.53141 	 	    0.62371
# std mean diff.........     64.261 	 	     22.092
#
# mean raw eQQ diff.....    0.14006 	 	   0.055646
# med  raw eQQ diff.....    0.16667 	 	          0
# max  raw eQQ diff.....    0.33333 	 	    0.16667
#
# mean eCDF diff........    0.12056 	 	   0.047697
# med  eCDF diff........    0.12599 	 	   0.028606
# max  eCDF diff........    0.26495 	 	    0.12219
#
# var ratio (Tr/Co).....     1.0145 	 	    0.97576
# T-test p-value........ < 2.22e-16 	 	  6.765e-06
# KS Bootstrap p-value.. < 2.22e-16 	 	 < 2.22e-16
# KS Naive p-value...... < 2.22e-16 	 	 2.2204e-16
# KS Statistic..........    0.26495 	 	    0.12219
#
#
# Before Matching Minimum p.value: < 2.22e-16
# Variable Name(s): etahat yGPA yKnowledge yNextSch pParticipate2 pEducHH pEducW pHHInc pKnowledge  Number(s): 1 2 6 7 10 12 13 14 17
#
# After Matching Minimum p.value: < 2.22e-16
# Variable Name(s): etahat yGPA yKnowledge pParticipate2 pEducHH pEducW pHHInc pKnowledge  Number(s): 1 2 6 10 12 13 14 17
# ***** (V1) outout *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.94645 	 	    0.94645
# mean control..........      0.949 	 	    0.98163
# std mean diff.........    -1.1326 	 	    -15.617
#
# mean raw eQQ diff.....  0.0044346 	 	   0.035145
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0012757 	 	   0.017573
# med  eCDF diff........  0.0012757 	 	   0.017573
# max  eCDF diff........  0.0025514 	 	   0.035145
#
# var ratio (Tr/Co).....     1.0462 	 	     2.8108
# T-test p-value........    0.84523 	 	 0.00014846
#
#
# ***** (V2) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.50311 	 	    0.50311
# mean control..........    0.37916 	 	    0.55882
# std mean diff.........     24.776 	 	    -11.135
#
# mean raw eQQ diff.....    0.12417 	 	   0.053535
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.061978 	 	   0.026767
# med  eCDF diff........   0.061978 	 	   0.026767
# max  eCDF diff........    0.12396 	 	   0.053535
#
# var ratio (Tr/Co).....      1.061 	 	      1.014
# T-test p-value........ 1.9671e-05 	 	   0.022717
#
#
# ***** (V3) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.31258 	 	    0.31258
# mean control..........    0.36142 	 	    0.29805
# std mean diff.........     -10.53 	 	     3.1323
#
# mean raw eQQ diff.....    0.04878 	 	   0.013895
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.024421 	 	  0.0069473
# med  eCDF diff........   0.024421 	 	  0.0069473
# max  eCDF diff........   0.048841 	 	   0.013895
#
# var ratio (Tr/Co).....     0.9301 	 	      1.027
# T-test p-value........   0.080821 	 	    0.52314
#
#
# ***** (V4) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.049813 	 	   0.049813
# mean control..........    0.08204 	 	   0.030594
# std mean diff.........    -14.804 	 	     8.8287
#
# mean raw eQQ diff.....   0.033259 	 	    0.01839
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.016113 	 	  0.0091949
# med  eCDF diff........   0.016113 	 	  0.0091949
# max  eCDF diff........   0.032227 	 	    0.01839
#
# var ratio (Tr/Co).....    0.62789 	 	     1.5959
# T-test p-value........   0.032512 	 	   0.049912
#
#
# ***** (V5) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.007472 	 	   0.007472
# mean control..........  0.0022173 	 	  0.0049813
# std mean diff.........      6.098 	 	     2.8904
#
# mean raw eQQ diff.....  0.0044346 	 	   0.002452
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0026273 	 	   0.001226
# med  eCDF diff........  0.0026273 	 	   0.001226
# max  eCDF diff........  0.0052547 	 	   0.002452
#
# var ratio (Tr/Co).....     3.3489 	 	     1.4962
# T-test p-value........    0.16289 	 	    0.52717
#
#
# ***** (V6) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.12702 	 	    0.12702
# mean control..........    0.17517 	 	    0.10756
# std mean diff.........    -14.448 	 	     5.8428
#
# mean raw eQQ diff.....    0.04878 	 	   0.018799
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.024071 	 	  0.0093993
# med  eCDF diff........   0.024071 	 	  0.0093993
# max  eCDF diff........   0.048143 	 	   0.018799
#
# var ratio (Tr/Co).....    0.76674 	 	     1.1552
# T-test p-value........   0.024947 	 	     0.2197
#
#
# ***** (V7) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........     0.4396 	 	     0.4396
# mean control..........    0.39468 	 	    0.68495
# std mean diff.........     9.0452 	 	    -49.401
#
# mean raw eQQ diff.....   0.044346 	 	    0.24234
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.022462 	 	    0.12117
# med  eCDF diff........   0.022462 	 	    0.12117
# max  eCDF diff........   0.044923 	 	    0.24234
#
# var ratio (Tr/Co).....     1.0302 	 	     1.1416
# T-test p-value........    0.12105 	 	 < 2.22e-16
#
#
# ***** (V8) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.15691 	 	    0.15691
# mean control..........     0.1663 	 	   0.095807
# std mean diff.........    -2.5788 	 	     16.789
#
# mean raw eQQ diff.....  0.0088692 	 	   0.059256
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0046928 	 	   0.029628
# med  eCDF diff........  0.0046928 	 	   0.029628
# max  eCDF diff........  0.0093855 	 	   0.059256
#
# var ratio (Tr/Co).....    0.95326 	 	     1.5271
# T-test p-value........    0.66619 	 	 0.00026395
#
#
# ***** (V9) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058531 	 	   0.058531
# mean control..........   0.066519 	 	   0.059402
# std mean diff.........    -3.4009 	 	   -0.37112
#
# mean raw eQQ diff.....  0.0088692 	 	 0.00081733
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0039942 	 	 0.00040866
# med  eCDF diff........  0.0039942 	 	 0.00040866
# max  eCDF diff........  0.0079883 	 	 0.00081733
#
# var ratio (Tr/Co).....    0.88657 	 	    0.98624
# T-test p-value........     0.5786 	 	    0.94164
#
#
# ***** (V10) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.013699 	 	   0.013699
# mean control..........   0.013304 	 	  0.0050851
# std mean diff.........    0.33949 	 	     7.4057
#
# mean raw eQQ diff.....          0 	 	  0.0081733
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          0 	 	          1
#
# mean eCDF diff........ 0.00019743 	 	  0.0040866
# med  eCDF diff........ 0.00019743 	 	  0.0040866
# max  eCDF diff........ 0.00039486 	 	  0.0081733
#
# var ratio (Tr/Co).....     1.0283 	 	     2.6706
# T-test p-value........     0.9536 	 	   0.068309
#
#
# ***** (V11) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.33126 	 	    0.33126
# mean control..........     0.3592 	 	    0.15475
# std mean diff.........    -5.9334 	 	     37.478
#
# mean raw eQQ diff.....   0.028825 	 	    0.17573
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.013972 	 	   0.087863
# med  eCDF diff........   0.013972 	 	   0.087863
# max  eCDF diff........   0.027944 	 	    0.17573
#
# var ratio (Tr/Co).....    0.96148 	 	     1.6936
# T-test p-value........    0.31969 	 	 < 2.22e-16
#
#
# ***** (V12) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.35492 	 	    0.35492
# mean control..........    0.40133 	 	    0.53174
# std mean diff.........    -9.6935 	 	     -36.93
#
# mean raw eQQ diff.....   0.046563 	 	    0.17123
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.023206 	 	   0.085615
# med  eCDF diff........   0.023206 	 	   0.085615
# max  eCDF diff........   0.046411 	 	    0.17123
#
# var ratio (Tr/Co).....    0.95199 	 	    0.91951
# T-test p-value........    0.10529 	 	 1.1318e-12
#
#
# ***** (V13) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.32752 	 	    0.32752
# mean control..........    0.31486 	 	    0.32352
# std mean diff.........     2.6972 	 	    0.85302
#
# mean raw eQQ diff.....   0.013304 	 	   0.002452
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.006333 	 	   0.001226
# med  eCDF diff........   0.006333 	 	   0.001226
# max  eCDF diff........   0.012666 	 	   0.002452
#
# var ratio (Tr/Co).....       1.02 	 	     1.0064
# T-test p-value........    0.64472 	 	    0.86279
#
#
# ***** (V14) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.17186 	 	    0.17186
# mean control..........    0.14634 	 	   0.078643
# std mean diff.........     6.7589 	 	     24.693
#
# mean raw eQQ diff.....    0.02439 	 	   0.090315
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.012757 	 	   0.045157
# med  eCDF diff........   0.012757 	 	   0.045157
# max  eCDF diff........   0.025514 	 	   0.090315
#
# var ratio (Tr/Co).....     1.1381 	 	     1.9642
# T-test p-value........    0.23197 	 	 2.2631e-08
#
#
# ***** (V15) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.031133 	 	   0.031133
# mean control..........   0.026608 	 	  0.0080946
# std mean diff.........     2.6042 	 	     13.257
#
# mean raw eQQ diff.....  0.0044346 	 	   0.023294
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0022629 	 	   0.011647
# med  eCDF diff........  0.0022629 	 	   0.011647
# max  eCDF diff........  0.0045257 	 	   0.023294
#
# var ratio (Tr/Co).....     1.1635 	 	     3.7568
# T-test p-value........     0.6428 	 	 0.00083114
#
#
# ***** (V16) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.11333 	 	    0.11333
# mean control..........    0.11086 	 	   0.058012
# std mean diff.........    0.77566 	 	     17.439
#
# mean raw eQQ diff.....  0.0022173 	 	   0.053944
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0012301 	 	   0.026972
# med  eCDF diff........  0.0012301 	 	   0.026972
# max  eCDF diff........  0.0024603 	 	   0.053944
#
# var ratio (Tr/Co).....     1.0184 	 	     1.8388
# T-test p-value........    0.89455 	 	 7.1509e-05
#
#
# ***** (V17) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.64757 	 	    0.64757
# mean control..........    0.43681 	 	     0.5445
# std mean diff.........     44.091 	 	     21.562
#
# mean raw eQQ diff.....    0.21064 	 	    0.10217
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.10538 	 	   0.051083
# med  eCDF diff........    0.10538 	 	   0.051083
# max  eCDF diff........    0.21076 	 	    0.10217
#
# var ratio (Tr/Co).....    0.92681 	 	    0.92018
# T-test p-value........ 5.8709e-13 	 	  2.929e-05
#
#
# ***** (V18) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.090909 	 	   0.090909
# mean control..........    0.11308 	 	   0.049066
# std mean diff.........    -7.7081 	 	     14.546
#
# mean raw eQQ diff.....   0.022173 	 	   0.040458
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.011086 	 	   0.020229
# med  eCDF diff........   0.011086 	 	   0.020229
# max  eCDF diff........   0.022173 	 	   0.040458
#
# var ratio (Tr/Co).....    0.82322 	 	     1.7713
# T-test p-value........    0.21971 	 	 0.00090031
#
#
# ***** (V19) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.26152 	 	    0.26152
# mean control..........    0.45011 	 	    0.40643
# std mean diff.........    -42.887 	 	    -32.955
#
# mean raw eQQ diff.....    0.18847 	 	    0.14262
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.094296 	 	   0.071312
# med  eCDF diff........   0.094296 	 	   0.071312
# max  eCDF diff........    0.18859 	 	    0.14262
#
# var ratio (Tr/Co).....    0.77952 	 	    0.80054
# T-test p-value........ 3.6646e-11 	 	 1.0256e-09
#
#
# ***** (V20) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........     0.4122 	 	     0.4122
# mean control..........    0.31042 	 	    0.48763
# std mean diff.........     20.665 	 	    -15.314
#
# mean raw eQQ diff.....      0.102 	 	   0.074377
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.050891 	 	   0.037188
# med  eCDF diff........   0.050891 	 	   0.037188
# max  eCDF diff........    0.10178 	 	   0.074377
#
# var ratio (Tr/Co).....     1.1308 	 	    0.96976
# T-test p-value........ 0.00027653 	 	   0.001996
#
#
# ***** (V21) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.43462 	 	    0.43462
# mean control..........    0.45011 	 	    0.40652
# std mean diff.........     -3.123 	 	     5.6657
#
# mean raw eQQ diff.....   0.015521 	 	   0.029015
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0077453 	 	   0.014508
# med  eCDF diff........  0.0077453 	 	   0.014508
# max  eCDF diff........   0.015491 	 	   0.029015
#
# var ratio (Tr/Co).....    0.99182 	 	     1.0185
# T-test p-value........     0.5967 	 	    0.25624
#
#
# ***** (V22) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.051059 	 	   0.051059
# mean control..........   0.055432 	 	   0.027293
# std mean diff.........    -1.9858 	 	      10.79
#
# mean raw eQQ diff.....  0.0044346 	 	   0.022885
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0021869 	 	   0.011443
# med  eCDF diff........  0.0021869 	 	   0.011443
# max  eCDF diff........  0.0043738 	 	   0.022885
#
# var ratio (Tr/Co).....    0.92446 	 	      1.825
# T-test p-value........    0.74225 	 	   0.013801
#
#
# ***** (V23) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.10212 	 	    0.10212
# mean control..........    0.18404 	 	    0.07856
# std mean diff.........    -27.037 	 	      7.775
#
# mean raw eQQ diff.....    0.08204 	 	   0.022477
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.040959 	 	   0.011238
# med  eCDF diff........   0.040959 	 	   0.011238
# max  eCDF diff........   0.081918 	 	   0.022477
#
# var ratio (Tr/Co).....    0.60999 	 	     1.2666
# T-test p-value........ 0.00011809 	 	   0.096162
#
#
# ***** (V24) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........     0.3188 	 	     0.3188
# mean control..........    0.22616 	 	    0.46492
# std mean diff.........     19.867 	 	    -31.336
#
# mean raw eQQ diff.....   0.093126 	 	    0.14508
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.04632 	 	   0.072538
# med  eCDF diff........    0.04632 	 	   0.072538
# max  eCDF diff........    0.09264 	 	    0.14508
#
# var ratio (Tr/Co).....     1.2397 	 	    0.87297
# T-test p-value........ 0.00032501 	 	 1.5312e-09
#
#
# ***** (V25) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.49315 	 	    0.49315
# mean control..........    0.41685 	 	    0.39587
# std mean diff.........     15.252 	 	     19.446
#
# mean raw eQQ diff.....   0.075388 	 	   0.098079
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.03815 	 	    0.04904
# med  eCDF diff........    0.03815 	 	    0.04904
# max  eCDF diff........   0.076299 	 	   0.098079
#
# var ratio (Tr/Co).....     1.0272 	 	     1.0451
# T-test p-value........  0.0090865 	 	 8.8324e-05
#
#
# ***** (V26) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.058531 	 	   0.058531
# mean control..........   0.070953 	 	   0.036218
# std mean diff.........    -5.2888 	 	      9.499
#
# mean raw eQQ diff.....   0.013304 	 	   0.021251
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0062115 	 	   0.010625
# med  eCDF diff........  0.0062115 	 	   0.010625
# max  eCDF diff........   0.012423 	 	   0.021251
#
# var ratio (Tr/Co).....    0.83513 	 	     1.5786
# T-test p-value........    0.39731 	 	   0.030518
#
#
# ***** (V27) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.12827 	 	    0.12827
# mean control..........    0.28603 	 	    0.10299
# std mean diff.........     -47.15 	 	     7.5554
#
# mean raw eQQ diff.....    0.15743 	 	    0.02452
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.078881 	 	    0.01226
# med  eCDF diff........   0.078881 	 	    0.01226
# max  eCDF diff........    0.15776 	 	    0.02452
#
# var ratio (Tr/Co).....      0.547 	 	     1.2104
# T-test p-value........ 1.7162e-10 	 	    0.10496
#
#
# ***** (V28) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.070984 	 	   0.070984
# mean control..........   0.084257 	 	    0.04643
# std mean diff.........    -5.1656 	 	     9.5556
#
# mean raw eQQ diff.....   0.013304 	 	   0.022477
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0066367 	 	   0.011238
# med  eCDF diff........  0.0066367 	 	   0.011238
# max  eCDF diff........   0.013273 	 	   0.022477
#
# var ratio (Tr/Co).....    0.85385 	 	     1.4895
# T-test p-value........    0.40487 	 	   0.034281
#
#
# ***** (V29) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.34745 	 	    0.34745
# mean control..........    0.32816 	 	    0.52107
# std mean diff.........     4.0481 	 	     -36.44
#
# mean raw eQQ diff.....   0.017738 	 	    0.17286
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0096437 	 	   0.086432
# med  eCDF diff........  0.0096437 	 	   0.086432
# max  eCDF diff........   0.019287 	 	    0.17286
#
# var ratio (Tr/Co).....     1.0274 	 	    0.90852
# T-test p-value........    0.48793 	 	 2.0415e-12
#
#
# ***** (V30) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.13076 	 	    0.13076
# mean control..........   0.093126 	 	   0.036405
# std mean diff.........     11.156 	 	      27.97
#
# mean raw eQQ diff.....   0.037694 	 	   0.093993
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.018817 	 	   0.046996
# med  eCDF diff........   0.018817 	 	   0.046996
# max  eCDF diff........   0.037633 	 	   0.093993
#
# var ratio (Tr/Co).....     1.3445 	 	     3.2401
# T-test p-value........   0.038366 	 	 1.3178e-11
#
#
# ***** (V31) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.45081 	 	    0.45081
# mean control..........    0.49446 	 	     0.3961
# std mean diff.........    -8.7666 	 	     10.989
#
# mean raw eQQ diff.....   0.044346 	 	   0.056396
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.021824 	 	   0.028198
# med  eCDF diff........   0.021824 	 	   0.028198
# max  eCDF diff........   0.043647 	 	   0.056396
#
# var ratio (Tr/Co).....    0.98948 	 	      1.035
# T-test p-value........    0.13795 	 	   0.025495
#
#
# ***** (V32) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.14819 	 	    0.14819
# mean control..........    0.21286 	 	     0.1384
# std mean diff.........    -18.189 	 	     2.7556
#
# mean raw eQQ diff.....   0.064302 	 	   0.011034
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.032333 	 	   0.005517
# med  eCDF diff........   0.032333 	 	   0.005517
# max  eCDF diff........   0.064666 	 	   0.011034
#
# var ratio (Tr/Co).....    0.75267 	 	     1.0586
# T-test p-value........  0.0050769 	 	     0.5703
#
#
# ***** (V33) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.22416 	 	    0.22416
# mean control..........    0.24834 	 	    0.40228
# std mean diff.........     -5.794 	 	    -42.686
#
# mean raw eQQ diff.....    0.02439 	 	    0.17859
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.012089 	 	   0.089293
# med  eCDF diff........   0.012089 	 	   0.089293
# max  eCDF diff........   0.024178 	 	    0.17859
#
# var ratio (Tr/Co).....    0.93077 	 	    0.72327
# T-test p-value........    0.33631 	 	 2.3537e-14
#
#
# ***** (V34) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........     0.1594 	 	     0.1594
# mean control..........    0.13747 	 	    0.16592
# std mean diff.........     5.9872 	 	    -1.7793
#
# mean raw eQQ diff.....   0.022173 	 	  0.0065386
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.010965 	 	  0.0032693
# med  eCDF diff........   0.010965 	 	  0.0032693
# max  eCDF diff........    0.02193 	 	  0.0065386
#
# var ratio (Tr/Co).....     1.1289 	 	    0.96823
# T-test p-value........    0.29084 	 	    0.72834
#
#
# ***** (V35) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.12453 	 	    0.12453
# mean control..........    0.15743 	 	   0.061831
# std mean diff.........    -9.9563 	 	     18.978
#
# mean raw eQQ diff.....   0.033259 	 	    0.06416
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.016447 	 	    0.03208
# med  eCDF diff........   0.016447 	 	    0.03208
# max  eCDF diff........   0.032895 	 	    0.06416
#
# var ratio (Tr/Co).....    0.82113 	 	     1.8795
# T-test p-value........    0.11333 	 	 1.6458e-05
#
#
# ***** (V36) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.099626 	 	   0.099626
# mean control..........   0.055432 	 	   0.027792
# std mean diff.........     14.747 	 	      23.97
#
# mean raw eQQ diff.....   0.044346 	 	   0.070699
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.022097 	 	   0.035349
# med  eCDF diff........   0.022097 	 	   0.035349
# max  eCDF diff........   0.044194 	 	   0.070699
#
# var ratio (Tr/Co).....     1.7115 	 	     3.3199
# T-test p-value........  0.0035068 	 	 5.2823e-09
#
#
# ***** (V37) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.14819 	 	    0.14819
# mean control..........    0.12195 	 	    0.17783
# std mean diff.........     7.3817 	 	    -8.3369
#
# mean raw eQQ diff.....   0.026608 	 	   0.030241
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.013122 	 	   0.015121
# med  eCDF diff........   0.013122 	 	   0.015121
# max  eCDF diff........   0.026243 	 	   0.030241
#
# var ratio (Tr/Co).....     1.1777 	 	    0.86337
# T-test p-value........    0.18719 	 	    0.10287
#
#
# ***** (V38) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.09589 	 	    0.09589
# mean control..........   0.066519 	 	   0.025944
# std mean diff.........     9.9692 	 	     23.741
#
# mean raw eQQ diff.....   0.028825 	 	   0.069473
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.014686 	 	   0.034736
# med  eCDF diff........   0.014686 	 	   0.034736
# max  eCDF diff........   0.029372 	 	   0.069473
#
# var ratio (Tr/Co).....     1.3948 	 	     3.4306
# T-test p-value........   0.061434 	 	 4.2408e-09
#
#
# ***** (V39) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.25903 	 	    0.25903
# mean control..........     0.1929 	 	    0.19371
# std mean diff.........     15.084 	 	       14.9
#
# mean raw eQQ diff.....   0.066519 	 	    0.06416
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.033062 	 	    0.03208
# med  eCDF diff........   0.033062 	 	    0.03208
# max  eCDF diff........   0.066124 	 	    0.06416
#
# var ratio (Tr/Co).....     1.2316 	 	     1.2289
# T-test p-value........  0.0063815 	 	   0.002028
#
#
# ***** (V40) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.37235 	 	    0.37235
# mean control..........    0.37029 	 	    0.58012
# std mean diff.........    0.42698 	 	     -42.95
#
# mean raw eQQ diff.....  0.0022173 	 	    0.20883
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0010327 	 	    0.10441
# med  eCDF diff........  0.0010327 	 	    0.10441
# max  eCDF diff........  0.0020654 	 	    0.20883
#
# var ratio (Tr/Co).....     1.0013 	 	    0.95946
# T-test p-value........    0.94215 	 	 < 2.22e-16
#
#
# ***** (V41) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.24408 	 	    0.24408
# mean control..........    0.27938 	 	    0.16434
# std mean diff.........    -8.2116 	 	     18.553
#
# mean raw eQQ diff.....   0.035477 	 	   0.080507
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.017647 	 	   0.040253
# med  eCDF diff........   0.017647 	 	   0.040253
# max  eCDF diff........   0.035294 	 	   0.080507
#
# var ratio (Tr/Co).....    0.91557 	 	     1.3435
# T-test p-value........    0.17543 	 	 5.8938e-05
#
#
# ***** (V42) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.48568 	 	    0.48568
# mean control..........    0.38803 	 	    0.61731
# std mean diff.........     19.526 	 	    -26.321
#
# mean raw eQQ diff.....   0.097561 	 	    0.12955
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.048826 	 	   0.064773
# med  eCDF diff........   0.048826 	 	   0.064773
# max  eCDF diff........   0.097652 	 	    0.12955
#
# var ratio (Tr/Co).....     1.0509 	 	     1.0574
# T-test p-value........ 0.00077906 	 	 7.5604e-08
#
#
# ***** (V43) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.43213 	 	    0.43213
# mean control..........     0.4878 	 	    0.21347
# std mean diff.........    -11.232 	 	     44.113
#
# mean raw eQQ diff.....   0.055432 	 	    0.21332
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.027838 	 	    0.10666
# med  eCDF diff........   0.027838 	 	    0.10666
# max  eCDF diff........   0.055675 	 	    0.21332
#
# var ratio (Tr/Co).....     0.9812 	 	     1.4615
# T-test p-value........   0.058114 	 	 < 2.22e-16
#
#
# ***** (V44) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.082192 	 	   0.082192
# mean control..........    0.12417 	 	    0.16922
# std mean diff.........    -15.274 	 	    -31.666
#
# mean raw eQQ diff.....   0.042129 	 	   0.083776
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.020988 	 	   0.041888
# med  eCDF diff........   0.020988 	 	   0.041888
# max  eCDF diff........   0.041977 	 	   0.083776
#
# var ratio (Tr/Co).....    0.69299 	 	    0.53659
# T-test p-value........   0.022226 	 	 1.4514e-07
#
#
# ***** (V45) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.17933 	 	    0.17933
# mean control..........    0.16851 	 	    0.22366
# std mean diff.........     2.8169 	 	    -11.549
#
# mean raw eQQ diff.....   0.011086 	 	   0.042092
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0054066 	 	   0.021046
# med  eCDF diff........  0.0054066 	 	   0.021046
# max  eCDF diff........   0.010813 	 	   0.042092
#
# var ratio (Tr/Co).....     1.0493 	 	    0.84757
# T-test p-value........    0.62703 	 	   0.026737
#
#
# ***** (V46) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.53923 	 	    0.53923
# mean control..........    0.52106 	 	    0.61235
# std mean diff.........     3.6417 	 	     -14.66
#
# mean raw eQQ diff.....   0.017738 	 	   0.071925
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0090818 	 	   0.035962
# med  eCDF diff........  0.0090818 	 	   0.035962
# max  eCDF diff........   0.018164 	 	   0.071925
#
# var ratio (Tr/Co).....    0.99464 	 	     1.0467
# T-test p-value........    0.53685 	 	  0.0029289
#
#
# ***** (V47) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.28144 	 	    0.28144
# mean control..........    0.31042 	 	    0.16399
# std mean diff.........    -6.4395 	 	     26.102
#
# mean raw eQQ diff.....   0.028825 	 	    0.11402
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.014488 	 	   0.057009
# med  eCDF diff........   0.014488 	 	   0.057009
# max  eCDF diff........   0.028977 	 	    0.11402
#
# var ratio (Tr/Co).....    0.94383 	 	     1.4751
# T-test p-value........    0.28308 	 	 1.4496e-08
#
#
# ***** (V48) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.25156 	 	    0.25156
# mean control..........    0.23503 	 	    0.20035
# std mean diff.........     3.8057 	 	     11.793
#
# mean raw eQQ diff.....   0.015521 	 	   0.049857
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0082617 	 	   0.024928
# med  eCDF diff........  0.0082617 	 	   0.024928
# max  eCDF diff........   0.016523 	 	   0.049857
#
# var ratio (Tr/Co).....     1.0462 	 	     1.1752
# T-test p-value........    0.51194 	 	   0.013975
#
#
# ***** (V49) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.55915 	 	    0.55915
# mean control..........    0.56098 	 	    0.65623
# std mean diff.........   -0.36684 	 	     -19.54
#
# mean raw eQQ diff.....  0.0022173 	 	   0.093584
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........ 0.00091122 	 	   0.046792
# med  eCDF diff........ 0.00091122 	 	   0.046792
# max  eCDF diff........  0.0018224 	 	   0.093584
#
# var ratio (Tr/Co).....    0.99991 	 	     1.0927
# T-test p-value........    0.95031 	 	 5.9306e-05
#
#
# ***** (V50) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.18929 	 	    0.18929
# mean control..........    0.20399 	 	    0.14342
# std mean diff.........    -3.7504 	 	     11.702
#
# mean raw eQQ diff.....   0.015521 	 	   0.043727
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0073505 	 	   0.021864
# med  eCDF diff........  0.0073505 	 	   0.021864
# max  eCDF diff........   0.014701 	 	   0.043727
#
# var ratio (Tr/Co).....    0.94415 	 	     1.2491
# T-test p-value........    0.53173 	 	   0.011996
#
#
# ***** (V51) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.45455 	 	    0.45455
# mean control..........    0.37694 	 	     0.4874
# std mean diff.........     15.576 	 	    -6.5944
#
# mean raw eQQ diff.....   0.077605 	 	    0.03065
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.038803 	 	   0.015325
# med  eCDF diff........   0.038803 	 	   0.015325
# max  eCDF diff........   0.077605 	 	    0.03065
#
# var ratio (Tr/Co).....     1.0547 	 	    0.99237
# T-test p-value........  0.0072265 	 	    0.17951
#
#
# ***** (V52) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.47572 	 	    0.47572
# mean control..........    0.52772 	 	    0.46243
# std mean diff.........    -10.406 	 	     2.6582
#
# mean raw eQQ diff.....   0.053215 	 	   0.011851
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........      0.026 	 	  0.0059256
# med  eCDF diff........      0.026 	 	  0.0059256
# max  eCDF diff........      0.052 	 	   0.011851
#
# var ratio (Tr/Co).....    0.99974 	 	     1.0033
# T-test p-value........    0.07735 	 	    0.58515
#
#
# ***** (V53) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.069738 	 	   0.069738
# mean control..........   0.095344 	 	   0.050166
# std mean diff.........    -10.047 	 	     7.6795
#
# mean raw eQQ diff.....   0.026608 	 	   0.018799
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.012803 	 	  0.0093993
# med  eCDF diff........   0.012803 	 	  0.0093993
# max  eCDF diff........   0.025605 	 	   0.018799
#
# var ratio (Tr/Co).....    0.75141 	 	     1.3615
# T-test p-value........     0.1213 	 	   0.093577
#
#
# ***** (V54) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.86924 	 	    0.86924
# mean control..........    0.83592 	 	    0.92879
# std mean diff.........     9.8771 	 	    -17.652
#
# mean raw eQQ diff.....   0.033259 	 	   0.057622
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.01666 	 	   0.028811
# med  eCDF diff........    0.01666 	 	   0.028811
# max  eCDF diff........    0.03332 	 	   0.057622
#
# var ratio (Tr/Co).....    0.82789 	 	     1.7185
# T-test p-value........     0.1152 	 	 0.00011086
#
#
# ***** (V55) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.011208 	 	   0.011208
# mean control..........  0.0088692 	 	  0.0014529
# std mean diff.........     2.2203 	 	     9.2607
#
# mean raw eQQ diff.....  0.0022173 	 	  0.0093993
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0011694 	 	  0.0046996
# med  eCDF diff........  0.0011694 	 	  0.0046996
# max  eCDF diff........  0.0023388 	 	  0.0093993
#
# var ratio (Tr/Co).....     1.2595 	 	     7.6389
# T-test p-value........    0.68558 	 	   0.013871
#
#
# ***** (V56) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.11955 	 	    0.11955
# mean control..........    0.15521 	 	   0.069759
# std mean diff.........    -10.984 	 	     15.338
#
# mean raw eQQ diff.....   0.035477 	 	   0.048222
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# ...
# mean control..........    0.11308 	 	    0.10633
# std mean diff.........    -20.313 	 	    -6.0739
#
# mean raw eQQ diff.....    0.04878 	 	   0.020107
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.024785 	 	   0.010054
# med  eCDF diff........   0.024785 	 	   0.010054
# max  eCDF diff........    0.04957 	 	   0.020107
#
# var ratio (Tr/Co).....    0.59246 	 	    0.85343
# T-test p-value........  0.0041391 	 	    0.29411
#
#
# ***** (V334) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.10212 	 	    0.11721
# mean control..........    0.13525 	 	    0.10074
# std mean diff.........    -10.937 	 	      5.116
#
# mean raw eQQ diff.....   0.033259 	 	   0.010724
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.016569 	 	  0.0053619
# med  eCDF diff........   0.016569 	 	  0.0053619
# max  eCDF diff........   0.033138 	 	   0.010724
#
# var ratio (Tr/Co).....    0.78317 	 	     1.1422
# T-test p-value........   0.087086 	 	    0.32636
#
#
# ***** (V335) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.19801 	 	    0.20623
# mean control..........    0.23947 	 	    0.13625
# std mean diff.........    -10.398 	 	     17.283
#
# mean raw eQQ diff.....   0.042129 	 	     0.0563
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.02073 	 	    0.02815
# med  eCDF diff........    0.02073 	 	    0.02815
# max  eCDF diff........    0.04146 	 	     0.0563
#
# var ratio (Tr/Co).....    0.87109 	 	      1.391
# T-test p-value........   0.091615 	 	 0.00070056
#
#
# ***** (V336) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.18431 	 	    0.15727
# mean control..........    0.15521 	 	    0.11578
# std mean diff.........        7.5 	 	     11.389
#
# mean raw eQQ diff.....   0.028825 	 	   0.037534
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.014549 	 	   0.018767
# med  eCDF diff........   0.014549 	 	   0.018767
# max  eCDF diff........   0.029098 	 	   0.037534
#
# var ratio (Tr/Co).....     1.1455 	 	     1.2946
# T-test p-value........     0.1839 	 	   0.026802
#
#
# ***** (V337) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.16687 	 	    0.14837
# mean control..........   0.084257 	 	     0.4093
# std mean diff.........     22.144 	 	    -73.351
#
# mean raw eQQ diff.....    0.08204 	 	    0.23458
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.041309 	 	    0.11729
# med  eCDF diff........   0.041309 	 	    0.11729
# max  eCDF diff........   0.082617 	 	    0.23458
#
# var ratio (Tr/Co).....     1.8001 	 	    0.52262
# T-test p-value........ 9.4522e-06 	 	 < 2.22e-16
#
#
# ***** (V338) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.16065 	 	    0.11128
# mean control..........   0.011086 	 	   0.024233
# std mean diff.........     40.704 	 	     27.658
#
# mean raw eQQ diff.....    0.14856 	 	    0.08445
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.074781 	 	   0.042225
# med  eCDF diff........   0.074781 	 	   0.042225
# max  eCDF diff........    0.14956 	 	    0.08445
#
# var ratio (Tr/Co).....     12.287 	 	     4.1822
# T-test p-value........ < 2.22e-16 	 	 2.4083e-10
#
#
# ***** (V339) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.84433 	 	    0.80564
# mean control..........    0.74279 	 	    0.79063
# std mean diff.........     27.991 	 	     3.7904
#
# mean raw eQQ diff.....   0.099778 	 	   0.018767
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.05077 	 	  0.0093834
# med  eCDF diff........    0.05077 	 	  0.0093834
# max  eCDF diff........    0.10154 	 	   0.018767
#
# var ratio (Tr/Co).....    0.68728 	 	    0.94593
# T-test p-value........ 3.1568e-05 	 	    0.48617
#
#
# ***** (V340) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.38107 	 	    0.30564
# mean control..........    0.17517 	 	     0.1433
# std mean diff.........     42.371 	 	     35.213
#
# mean raw eQQ diff.....    0.20621 	 	    0.13405
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.10295 	 	   0.067024
# med  eCDF diff........    0.10295 	 	   0.067024
# max  eCDF diff........     0.2059 	 	    0.13405
#
# var ratio (Tr/Co).....     1.6308 	 	     1.7287
# T-test p-value........ 4.4409e-16 	 	 5.9135e-12
#
#
# ***** (V341) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.54545 	 	    0.45549
# mean control..........    0.28381 	 	    0.60012
# std mean diff.........     52.513 	 	    -29.021
#
# mean raw eQQ diff.....    0.26164 	 	    0.13271
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.13082 	 	   0.066354
# med  eCDF diff........    0.13082 	 	   0.066354
# max  eCDF diff........    0.26164 	 	    0.13271
#
# var ratio (Tr/Co).....     1.2186 	 	     1.0335
# T-test p-value........ < 2.22e-16 	 	 8.7804e-08
#
#
# ***** (V342) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.28643 	 	    0.23294
# mean control..........    0.15965 	 	    0.17043
# std mean diff.........     28.026 	 	     14.778
#
# mean raw eQQ diff.....    0.12639 	 	   0.042895
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.06339 	 	   0.021448
# med  eCDF diff........    0.06339 	 	   0.021448
# max  eCDF diff........    0.12678 	 	   0.042895
#
# var ratio (Tr/Co).....      1.522 	 	     1.2638
# T-test p-value........ 8.5564e-08 	 	  0.0045066
#
#
# ***** (V343) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.96513 	 	    0.93917
# mean control..........    0.89357 	 	    0.99135
# std mean diff.........     38.984 	 	    -21.813
#
# mean raw eQQ diff.....   0.070953 	 	   0.052279
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.03578 	 	   0.026139
# med  eCDF diff........    0.03578 	 	   0.026139
# max  eCDF diff........   0.071561 	 	   0.052279
#
# var ratio (Tr/Co).....    0.35352 	 	     6.6586
# T-test p-value........ 8.2252e-06 	 	 1.7301e-07
#
#
# ***** (V344) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.89913 	 	    0.83828
# mean control..........     0.7561 	 	    0.85856
# std mean diff.........     47.464 	 	     -5.503
#
# mean raw eQQ diff.....    0.14191 	 	   0.018767
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.071515 	 	  0.0093834
# med  eCDF diff........   0.071515 	 	  0.0093834
# max  eCDF diff........    0.14303 	 	   0.018767
#
# var ratio (Tr/Co).....    0.49133 	 	     1.1164
# T-test p-value........ 6.9079e-10 	 	    0.30475
#
#
# ***** (V345) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.95517 	 	    0.93917
# mean control..........    0.92018 	 	    0.98813
# std mean diff.........     16.899 	 	    -20.469
#
# mean raw eQQ diff.....   0.033259 	 	   0.045576
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.017495 	 	   0.022788
# med  eCDF diff........   0.017495 	 	   0.022788
# max  eCDF diff........   0.034991 	 	   0.045576
#
# var ratio (Tr/Co).....    0.58243 	 	     4.8711
# T-test p-value........   0.017685 	 	 2.0138e-06
#
#
# ***** (V346) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.022416 	 	   0.034125
# mean control..........   0.068736 	 	  0.0066766
# std mean diff.........    -31.271 	 	     15.108
#
# mean raw eQQ diff.....   0.046563 	 	   0.024129
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.02316 	 	   0.012064
# med  eCDF diff........    0.02316 	 	   0.012064
# max  eCDF diff........    0.04632 	 	   0.024129
#
# var ratio (Tr/Co).....      0.342 	 	     4.9699
# T-test p-value........ 0.00040331 	 	 0.00039572
#
#
# ***** (V347) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.083437 	 	    0.12166
# mean control..........     0.1796 	 	    0.14491
# std mean diff.........    -34.752 	 	    -7.1054
#
# mean raw eQQ diff.....   0.095344 	 	   0.018767
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.048082 	 	  0.0093834
# med  eCDF diff........   0.048082 	 	  0.0093834
# max  eCDF diff........   0.096164 	 	   0.018767
#
# var ratio (Tr/Co).....    0.51852 	 	    0.86241
# T-test p-value........ 3.4829e-06 	 	    0.21542
#
#
# ***** (V348) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.24284 	 	    0.27448
# mean control..........     0.3459 	 	    0.19451
# std mean diff.........    -24.019 	 	     17.907
#
# mean raw eQQ diff.....    0.10421 	 	   0.071046
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.051529 	 	   0.035523
# med  eCDF diff........   0.051529 	 	   0.035523
# max  eCDF diff........    0.10306 	 	   0.071046
#
# var ratio (Tr/Co).....    0.81188 	 	      1.271
# T-test p-value........  0.0001495 	 	 0.00057798
#
#
# ***** (V349) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.28518 	 	    0.27448
# mean control..........    0.22616 	 	    0.47755
# std mean diff.........     13.063 	 	    -45.471
#
# mean raw eQQ diff.....    0.05765 	 	    0.17158
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029508 	 	   0.085791
# med  eCDF diff........   0.029508 	 	   0.085791
# max  eCDF diff........   0.059016 	 	    0.17158
#
# var ratio (Tr/Co).....     1.1636 	 	    0.79817
# T-test p-value........   0.020155 	 	 4.5297e-14
#
#
# ***** (V350) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.19303 	 	    0.16172
# mean control..........    0.11308 	 	   0.092038
# std mean diff.........     20.243 	 	     18.912
#
# mean raw eQQ diff.....   0.079823 	 	   0.060322
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.039972 	 	   0.030161
# med  eCDF diff........   0.039972 	 	   0.030161
# max  eCDF diff........   0.079944 	 	   0.060322
#
# var ratio (Tr/Co).....     1.5516 	 	     1.6223
# T-test p-value........ 9.6168e-05 	 	 0.00012899
#
#
# ***** (V351) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.16812 	 	    0.11721
# mean control..........   0.042129 	 	   0.083581
# std mean diff.........     33.669 	 	     10.447
#
# mean raw eQQ diff.....    0.12639 	 	   0.018767
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.062995 	 	  0.0093834
# med  eCDF diff........   0.062995 	 	  0.0093834
# max  eCDF diff........    0.12599 	 	   0.018767
#
# var ratio (Tr/Co).....     3.4624 	 	     1.3509
# T-test p-value........  1.843e-14 	 	   0.042662
#
#
# ***** (V352) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.44707 	 	    0.41543
# mean control..........    0.38803 	 	    0.73242
# std mean diff.........     11.869 	 	    -64.277
#
# mean raw eQQ diff.....    0.05765 	 	     0.2815
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029523 	 	    0.14075
# med  eCDF diff........   0.029523 	 	    0.14075
# max  eCDF diff........   0.059047 	 	     0.2815
#
# var ratio (Tr/Co).....       1.04 	 	     1.2391
# T-test p-value........   0.041401 	 	 < 2.22e-16
#
#
# ***** (V353) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.92777 	 	    0.92285
# mean control..........      0.898 	 	     0.9754
# std mean diff.........     11.492 	 	    -19.678
#
# mean raw eQQ diff.....   0.028825 	 	   0.052279
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.014883 	 	   0.026139
# med  eCDF diff........   0.014883 	 	   0.026139
# max  eCDF diff........   0.029766 	 	   0.052279
#
# var ratio (Tr/Co).....    0.73092 	 	     2.9668
# T-test p-value........   0.079332 	 	 1.6744e-05
#
#
# ***** (V354) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.064757 	 	   0.063798
# mean control..........   0.088692 	 	   0.024604
# std mean diff.........    -9.7196 	 	     16.025
#
# mean raw eQQ diff.....    0.02439 	 	   0.037534
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.011967 	 	   0.018767
# med  eCDF diff........   0.011967 	 	   0.018767
# max  eCDF diff........   0.023935 	 	   0.037534
#
# var ratio (Tr/Co).....    0.74858 	 	     2.4888
# T-test p-value........    0.13439 	 	 0.00059039
#
#
# ***** (V355) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.007472 	 	   0.013353
# mean control..........   0.013304 	 	          0
# std mean diff.........    -6.7677 	 	     11.625
#
# mean raw eQQ diff.....  0.0066519 	 	   0.014745
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........  0.0029159 	 	  0.0073727
# med  eCDF diff........  0.0029159 	 	  0.0073727
# max  eCDF diff........  0.0058318 	 	   0.014745
#
# var ratio (Tr/Co).....    0.56441 	 	        Inf
# T-test p-value........    0.34707 	 	  0.0026215
#
#
# Before Matching Minimum p.value: < 2.22e-16
# Variable Name(s): out out out out out out out out out out out  Number(s): 105 106 109 110 117 220 266 282 328 338 341
#
# After Matching Minimum p.value: < 2.22e-16
# Variable Name(s): out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out out  Number(s): 35 42 43 66 68 76 78 82 84 91 110 112 119 138 139 147 160 178 190 205 209 220 222 233 270 275 282 284 298 300 310 311 327 337 352
#      bf.bal    af.bal
# [1,] 0.4084507 0.2732394
# Estimate...  0.37475
# AI SE......  0.79043
# T-stat.....  0.47411
# p.val......  0.63542
#
# Original number of observations..............  1045
# Original number of treated obs...............  674
# Matched number of observations...............  674
# Matched number of observations  (unweighted).  742
# [1] 0.6403509
# [1] 0.8338374
# [1] 0.2958504
# [1] 0.3512628
# [1] 0.08781569
#       419
# 0.8280431
#       855
# 0.9998174
# [1] 0.9999998
# [1] 0.02330369
# [1] 0.9889442
# [1] 1.196065e-10
# [1] 0.03104213
# [1] 0.01108647
# [1] 1.019956
# [1] 0.7937916
# [1] 0.1714514
# [1] 0.05582137
#  337  595  676  723 1061
#  134  239  265  283  391
#       337       595      1061       676       723
# 0.9533107 0.9648332 0.9735553 0.9821213 0.9889442
# [1] 60
# [1] 58
# [1] 316
# [1] 287
# [1] 335
# [1] 0.02451982
# [1] 0.02370249
# [1] 0.1291377
# [1] 0.1172865
# [1] 0.1369023
# [1] 0.4315488
# [1] 3.26257
# [1] 4
# [1] 2.793275
# [1] 1.427938
# [1] 3.319355
# [1] 4.4
# [1] 3.041543
# [1] 1.976064
