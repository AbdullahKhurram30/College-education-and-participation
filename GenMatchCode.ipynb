# %%
#######################
#   John Henderson    #
#    UC-Berkeley      #            
#       &             #
#   Sara Chatfield    #
#    UC-Berkeley      #       
#                     # 
#    Who Matches:     #
#   Replication Code  #
#                     #
#   Released          #
#     Version 1.0     #
#                     #
#   Nov 17, 2010      #
#######################


# USAGE
#########################################  
# This is replication code for Henderson, John, and Sara Chatfield. 2011. "Who Matches? Propensity Scores and Bias in the Causal Effects
# of Education on Participation," Journal of Politics.  The software, code, and data may be used, distributed, and modified freely 
# with proper attribution to both Henderson and Chatfield (2011) and Kam and Palmer (2008). 


# DESCRPITION
#########################################                                                                       
# The following code replicates the genetic matching analysis conducted in 'Who Matches'.  In training our genetic matching
# runs, we made a series of customizations aimed at optimizing balance in covariates. The first of these is the use of a different
# loss function than that which is used in the standard GenMatch package.  We optimize the proportion of all covariates that are 
# balanced across treatment and control groups at the p > .1 level. Note that these are all t-tests since all covariates are 
# dichotomized following Kam and Palmer (2008).  This loss function is 'lower.bound' and is described in greater detail in the 
# funcs.R file.      
#
# The second unique specification is that we use two different propensity scores as starting points in our genetic matching 
# runs.  A typical way to use propensity scores in a genetic matching run is to create a matrix X that includes the covariates 
# that GenMatch will match on, and attach the p-score to this matrix so that GenMatch will search for matching weights for the 
# X covariates plus a p-score P.  We simply attach P1 and P2 to X and match on this matrix.  To speed up the GenMatch runs, we 
# also orthogonalize X by regressing each covariate vector on P1 and then on P2, extracting the residuals to form the final matching 
# matrix.  Though this isnt necessary, it greatly speeds up the optimization procedure since it ensures that GenMatch only matches 
# on information in X that is orthogonal to P1 and P2. 
#
# Three final things: First, we check balance and match on a matrix object 'out', which is produced by dichotomizing an expanded set of covariates 
# that include the original 81 used in Kam and Palmer (2008) plus an additional 28 covariates.  Dichotomizing these covariates 
# produces a matrix of 1254 x 355.  Second, the results below represent the final product from a very long series of GenMatch 
# trainings.  The GenMatch weights objects 'starts' are the weights supplied by GenMatch from our final run, and thus are used here 
# to recover the final ATT and ATC estimates.  To replicate the actual GenMatch runs we conducted, you will need to create a new 
# 'starts' vector that has 100 in the first two elements and 0s in the remaining 355, and increase the 'pop.size' and 'max.generations' 
# to sufficiently large values to get improvements.  
# 
# Finally, this code sources both the funcs.R file and the objects.R file.  The former contains the relevant functions used here to 
# conduct our analysis, and the latter contains the code that transforms the original dataset into the various matrix objects used
# in GenMatch.  The indicator.Rdata contains the 'indicator' object that is the matrix used in the 766642 permutations of the 81 
# covariates.  Here it is modified to just include the best two ATT and two ATC propensity scores.
            

library(MASS)
library(Matching)
load("WhoMatches.Rdata")
source('funcs.R')   
load('indicator.Rdata')

# %%
source('objects.R')

# %%
floors=NULL
floor.values=NULL
reweighted = -1
attach(data_rep)
attach(factors)


# BEST GENMATCH

#ATT: prob 1 to 3

matTemp=as.matrix(original)%*%diag(indicator[1,])   #363708
temp=list()
for(i in 1:81){
	if(indicator[1,i]==1){
		temp[[i]]=factor(matTemp[,i])
	}
	else{
		temp[[i]]=matTemp[,i]
	}
}

pscore=glm(college~temp[[1]]+temp[[2]]+temp[[3]]+temp[[4]]+temp[[5]]+temp[[6]]+temp[[7]]+temp[[8]]+temp[[9]]+temp[[10]]+temp[[11]]+temp[[12]]+temp[[13]]+temp[[14]]+temp[[15]]+temp[[16]]+temp[[17]]+temp[[18]]+temp[[19]]+temp[[20]]+temp[[21]]+
	temp[[22]]+temp[[23]]+temp[[24]]+temp[[25]]+temp[[26]]+temp[[27]]+temp[[28]]+temp[[29]]+temp[[30]]+temp[[31]]+temp[[32]]+temp[[33]]+temp[[34]]+temp[[35]]+temp[[36]]+temp[[37]]+temp[[38]]+temp[[39]]+temp[[40]]+temp[[41]]+temp[[42]]+
	temp[[43]]+temp[[44]]+temp[[45]]+temp[[46]]+temp[[47]]+temp[[48]]+temp[[49]]+temp[[50]]+temp[[51]]+temp[[52]]+temp[[53]]+temp[[54]]+temp[[55]]+temp[[56]]+temp[[57]]+temp[[58]]+temp[[59]]+temp[[60]]+temp[[61]]+temp[[62]]+temp[[63]]+
	temp[[64]]+temp[[65]]+temp[[66]]+temp[[67]]+temp[[68]]+temp[[69]]+temp[[70]]+temp[[71]]+temp[[72]]+temp[[73]]+temp[[74]]+temp[[75]]+temp[[76]]+temp[[77]]+temp[[78]]+temp[[79]]+temp[[80]]+temp[[81]],family=binomial(link=logit))  
etahat1=pscore$fitted.values


matTemp=as.matrix(original)%*%diag(indicator[2,])    #388106
temp=list()
for(i in 1:81){
	if(indicator[2,i]==1){
		temp[[i]]=factor(matTemp[,i])
	}
	else{
		temp[[i]]=matTemp[,i]
	}
}

pscore=glm(college~temp[[1]]+temp[[2]]+temp[[3]]+temp[[4]]+temp[[5]]+temp[[6]]+temp[[7]]+temp[[8]]+temp[[9]]+temp[[10]]+temp[[11]]+temp[[12]]+temp[[13]]+temp[[14]]+temp[[15]]+temp[[16]]+temp[[17]]+temp[[18]]+temp[[19]]+temp[[20]]+temp[[21]]+
	temp[[22]]+temp[[23]]+temp[[24]]+temp[[25]]+temp[[26]]+temp[[27]]+temp[[28]]+temp[[29]]+temp[[30]]+temp[[31]]+temp[[32]]+temp[[33]]+temp[[34]]+temp[[35]]+temp[[36]]+temp[[37]]+temp[[38]]+temp[[39]]+temp[[40]]+temp[[41]]+temp[[42]]+
	temp[[43]]+temp[[44]]+temp[[45]]+temp[[46]]+temp[[47]]+temp[[48]]+temp[[49]]+temp[[50]]+temp[[51]]+temp[[52]]+temp[[53]]+temp[[54]]+temp[[55]]+temp[[56]]+temp[[57]]+temp[[58]]+temp[[59]]+temp[[60]]+temp[[61]]+temp[[62]]+temp[[63]]+
	temp[[64]]+temp[[65]]+temp[[66]]+temp[[67]]+temp[[68]]+temp[[69]]+temp[[70]]+temp[[71]]+temp[[72]]+temp[[73]]+temp[[74]]+temp[[75]]+temp[[76]]+temp[[77]]+temp[[78]]+temp[[79]]+temp[[80]]+temp[[81]],family=binomial(link=logit))  
etahat2=pscore$fitted.values

Xmat=cbind(etahat1,out)
for(i in 2:ncol(Xmat)){
	Xmat[,i]=lm(Xmat[,i]~etahat1)$residuals
}

Xmat=cbind(etahat2,Xmat)
for(i in 3:ncol(Xmat)){
	Xmat[,i]=lm(Xmat[,i]~etahat2)$residuals
}


starts=c(99.99925,100.0053,0.005715251,0.006408247,2.980232e-08,2.980232e-08,0.006262702,0.008668285,2.980232e-08,0.002887763,2.980232e-08,0.0009998784,0.002455857,0.003635949,2.980232e-08,2.980232e-08,2.980232e-08,0.00787601,0.006441565,
	0.006882892,0.004390646,0.001944808,0.005531695,2.980232e-08,0.008536832,0.006503187,2.980232e-08,0.009334766,0.00209233,2.980232e-08,2.980232e-08,2.980232e-08,0.009141416,0.006710892,2.980232e-08,0.00375902,2.980232e-08,2.980232e-08,
	0.002394659,0.002549385,2.980232e-08,0.001481797,0.008610365,2.980232e-08,2.980232e-08,2.980232e-08,0.009984436,0.006574805,0.002360336,0.00822486,2.980232e-08,2.980232e-08,0.004001202,0.007789226,2.980232e-08,0.008463702,0.006892591,
	2.980232e-08,0.003049413,2.980232e-08,0.001608269,0.004021724,0.009204788,0.001364288,0.001575996,2.980232e-08,0.008038192,2.980232e-08,0.007762872,2.980232e-08,0.005283075,0.003295967,2.980232e-08,2.980232e-08,0.004179459,173.6054,
	0.002824357,0.001318068,0.008916264,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,0.007247979,2.980232e-08,0.006996465,2.980232e-08,0.009502948,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,0.007643543,2.980232e-08,
	2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,0.004981017,0.000132719,0.00259975,0.007494614,855.7601,0.003140685,2.980232e-08,2.980232e-08,2.980232e-08,0.005202841,2.980232e-08,0.009273753,2.980232e-08,0.00141859,2.980232e-08,
	0.002784641,0.008928815,2.980232e-08,2.980232e-08,0.005609324,2.980232e-08,0.007712388,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,0.001323451,0.004780747,0.001246533,2.980232e-08,0.008068434,2.980232e-08,2.980232e-08,0.001275443,
	0.003073698,0.003277063,2.980232e-08,2.980232e-08,2.980232e-08,0.004064664,0.008520083,2.980232e-08,0.006505253,0.005767007,0.00651125,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,0.004590578,0.005835394,2.980232e-08,2.980232e-08,
	2.980232e-08,0.003976639,2.980232e-08,2.980232e-08,2.980232e-08,0.00442357,2.980232e-08,0.0001809476,2.980232e-08,2.980232e-08,0.00434598,0.004373333,2.980232e-08,0.001005735,0.009737443,2.980232e-08,2.980232e-08,0.002011738,2.980232e-08,
	0.006726748,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,0.0055867,42.69455,2.980232e-08,0.000141961,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,0.001291604,0.007333195,2.980232e-08,
	0.008610143,0.0007476773,2.980232e-08,2.980232e-08,0.004024254,0.00452202,0.001858119,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,0.009335303,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,
	0.007920756,2.980232e-08,0.00153351,0.006578747,2.980232e-08,2.980232e-08,2.980232e-08,0.003463541,2.980232e-08,2.980232e-08,2.980232e-08,603.442,0.001144914,0.007914557,2.980232e-08,2.980232e-08,0.003372544,0.007569384,0.004901839,
	2.980232e-08,2.980232e-08,0.0008925979,2.980232e-08,0.005461286,0.008944928,0.0009883558,0.003052224,0.003033079,2.980232e-08,0.008314635,0.0003773529,2.980232e-08,2.980232e-08,0.009716536,288.4406,2.980232e-08,2.980232e-08,2.980232e-08,
	2.980232e-08,0.008213271,69.9943,2.980232e-08,0.002875351,0.00960413,0.007875248,0.005444037,2.980232e-08,0.003010958,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,0.006345055,2.980232e-08,0.005951712,0.0086756,2.980232e-08,2.980232e-08,
	0.0003141093,2.980232e-08,2.980232e-08,0.009148151,0.004543724,2.980232e-08,2.980232e-08,0.003030723,0.006520301,0.008936021,0.002618584,0.000648524,2.980232e-08,0.009145669,0.002337948,2.980232e-08,0.008956889,0.009425506,0.004757528,
	0.006359484,2.980232e-08,0.0002088765,0.007746522,2.980232e-08,2.980232e-08,2.980232e-08,392.4657,367.7674,2.980232e-08,0.001256075,2.980232e-08,2.980232e-08,0.009527099,0.009801216,0.002811012,0.006189428,0.00491197,2.980232e-08,2.980232e-08,
	2.980232e-08,2.980232e-08,0.004988182,2.980232e-08,0.00495712,2.980232e-08,0.007826605,0.002538008,2.980232e-08,0.002917703,0.003391779,2.980232e-08,0.009305687,2.980232e-08,2.980232e-08,1.891728e-08,9.624347e-05,0.0099455,0.006561823,
	0.008582851,2.980232e-08,0.008440943,0.006461001,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,2.980232e-08,0.005128652,0.009732047,2.980232e-08,0.002760089,2.980232e-08,2.980232e-08,2.980232e-08,0.00739862,
	0.007434984,2.980232e-08,0.0009944195,481.6896,0.00836362,2.980232e-08,0.008689271,2.980232e-08,0.003735749,2.980232e-08,0.00951215,0.003202765,2.980232e-08)

genout_m1=GenMatch(fit.func=lower.bound, Tr=college, X=Xmat, BalanceMatrix=out, estimand='ATT', M = 3, pop.size=1, max.generations=1, wait.generations=1, hard.generation.limit=F, starting.values=starts, nboots=0, ties=T, MemoryMatrix=F)	

1973

mout_m1=Match(Y=yppnscal,Tr=college, X=Xmat, estimand='ATT', M = 3, ties=T, Weight.matrix=genout_m1) 
summary(mout_m1)

matbal_m1 = MatchBalance(college ~ yGPA + yGen + yBlack + yRep+ yKnowledge + yNextSch + pVote + pPersuade + pParticipate2 + pEmploy + pEducHH + pEducW + pHHInc + pOwnHome + pRep  + pKnowledge, match.out = mout_m1,nboots=1000)
matbal_all1=MatchBalance(college ~ out, match.out = mout_m1)
mb1=percent.bal(matbal_all1)
mb1[[1]] # 0.4084507 :: 0.7098592

# Sensitivity Test

gamma_m1=hl.rbound(mout_m1, gamma=c(2,3,4,5), pr=.01, Y=yppnscal, paired=TRUE)

1982

mout_m4=Match(Y=y1982yppnscal[!is.na(y1982yppnscal)],Tr=college[!is.na(y1982yppnscal)], X=Xmat[!is.na(y1982yppnscal),], estimand='ATT', M = 3, ties=T, Weight.matrix=genout_m1) 
summary(mout_m4)

matbal_m4 = MatchBalance(college ~ yGPA + yGen + yBlack + yRep+ yKnowledge + yNextSch + pVote + pPersuade + pParticipate2 + pEmploy + pEducHH + pEducW + pHHInc + pOwnHome + pRep  + pKnowledge, match.out = mout_m4,nboots=1000)
matbal_all4=MatchBalance(college ~ out, match.out = mout_m4)
mb4=percent.bal(matbal_all4)
mb4[[1]] # 0.4084507 :: 0.5887324

# Sensitivity Test

gamma_m4=hl.rbound(mout_m4, gamma=c(2,3,4,5), pr=.01, Y=y1982yppnscal[!is.na(y1982yppnscal)], paired=TRUE)



#ATC: lin 1 to 3

matTemp=as.matrix(original)%*%diag(indicator[3,])   #469561
temp=list()
for(i in 1:81){
	if(indicator[3,i]==1){
		temp[[i]]=factor(matTemp[,i])
	}
	else{
		temp[[i]]=matTemp[,i]
	}
}

pscore=glm(college~temp[[1]]+temp[[2]]+temp[[3]]+temp[[4]]+temp[[5]]+temp[[6]]+temp[[7]]+temp[[8]]+temp[[9]]+temp[[10]]+temp[[11]]+temp[[12]]+temp[[13]]+temp[[14]]+temp[[15]]+temp[[16]]+temp[[17]]+temp[[18]]+temp[[19]]+temp[[20]]+temp[[21]]+
	temp[[22]]+temp[[23]]+temp[[24]]+temp[[25]]+temp[[26]]+temp[[27]]+temp[[28]]+temp[[29]]+temp[[30]]+temp[[31]]+temp[[32]]+temp[[33]]+temp[[34]]+temp[[35]]+temp[[36]]+temp[[37]]+temp[[38]]+temp[[39]]+temp[[40]]+temp[[41]]+temp[[42]]+
	temp[[43]]+temp[[44]]+temp[[45]]+temp[[46]]+temp[[47]]+temp[[48]]+temp[[49]]+temp[[50]]+temp[[51]]+temp[[52]]+temp[[53]]+temp[[54]]+temp[[55]]+temp[[56]]+temp[[57]]+temp[[58]]+temp[[59]]+temp[[60]]+temp[[61]]+temp[[62]]+temp[[63]]+
	temp[[64]]+temp[[65]]+temp[[66]]+temp[[67]]+temp[[68]]+temp[[69]]+temp[[70]]+temp[[71]]+temp[[72]]+temp[[73]]+temp[[74]]+temp[[75]]+temp[[76]]+temp[[77]]+temp[[78]]+temp[[79]]+temp[[80]]+temp[[81]],family=binomial(link=logit))  
etahat1=pscore$linear.predictors


matTemp=as.matrix(original)%*%diag(indicator[4,])    #585646
temp=list()
for(i in 1:81){
	if(indicator[4,i]==1){
		temp[[i]]=factor(matTemp[,i])
	}
	else{
		temp[[i]]=matTemp[,i]
	}
}

pscore=glm(college~temp[[1]]+temp[[2]]+temp[[3]]+temp[[4]]+temp[[5]]+temp[[6]]+temp[[7]]+temp[[8]]+temp[[9]]+temp[[10]]+temp[[11]]+temp[[12]]+temp[[13]]+temp[[14]]+temp[[15]]+temp[[16]]+temp[[17]]+temp[[18]]+temp[[19]]+temp[[20]]+temp[[21]]+
	temp[[22]]+temp[[23]]+temp[[24]]+temp[[25]]+temp[[26]]+temp[[27]]+temp[[28]]+temp[[29]]+temp[[30]]+temp[[31]]+temp[[32]]+temp[[33]]+temp[[34]]+temp[[35]]+temp[[36]]+temp[[37]]+temp[[38]]+temp[[39]]+temp[[40]]+temp[[41]]+temp[[42]]+
	temp[[43]]+temp[[44]]+temp[[45]]+temp[[46]]+temp[[47]]+temp[[48]]+temp[[49]]+temp[[50]]+temp[[51]]+temp[[52]]+temp[[53]]+temp[[54]]+temp[[55]]+temp[[56]]+temp[[57]]+temp[[58]]+temp[[59]]+temp[[60]]+temp[[61]]+temp[[62]]+temp[[63]]+
	temp[[64]]+temp[[65]]+temp[[66]]+temp[[67]]+temp[[68]]+temp[[69]]+temp[[70]]+temp[[71]]+temp[[72]]+temp[[73]]+temp[[74]]+temp[[75]]+temp[[76]]+temp[[77]]+temp[[78]]+temp[[79]]+temp[[80]]+temp[[81]],family=binomial(link=logit))  
etahat2=pscore$linear.predictors

Xmat=NULL
Xmat=cbind(etahat1,out)
for(i in 2:ncol(Xmat)){
	Xmat[,i]=lm(Xmat[,i]~etahat1)$residuals
}

Xmat=cbind(etahat2,Xmat)
for(i in 3:ncol(Xmat)){
	Xmat[,i]=lm(Xmat[,i]~etahat2)$residuals
}

starts=c(100,100.0071,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,739.1417,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,
	1.490116e-08,1.490116e-08,1.490116e-08,0.004539034,1.490116e-08,1.490116e-08,0.01517012,0.02992871,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.007834871,1.490116e-08,
	1.490116e-08,0.008113991,0.005919858,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.003814568,0.02419358,1.490116e-08,0.004334319,1.490116e-08,0.01948788,1.490116e-08,1.490116e-08,44.08746,
	1.490116e-08,1.490116e-08,13.53873,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.02696651,1.490116e-08,1.490116e-08,0.006232587,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.004892858,
	1.490116e-08,0.01903991,1.490116e-08,0.02379703,1.490116e-08,1.490116e-08,1.490116e-08,0.0034652,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,
	1.490116e-08,1.490116e-08,0.01299434,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.008628191,1.490116e-08,0.01575408,1.490116e-08,1.490116e-08,
	1.490116e-08,0.02771047,0.008514462,1.490116e-08,1.490116e-08,1.490116e-08,0.01750806,1.490116e-08,0.01683012,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.02491207,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,354.155,
	1.490116e-08,0.001847714,0.002439044,1.490116e-08,1.490116e-08,1.490116e-08,0.006686551,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,310.5782,1.490116e-08,1.490116e-08,0.01970852,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,
	1.490116e-08,1.490116e-08,0.007031653,1.490116e-08,1.490116e-08,0.01494422,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.007390262,1.490116e-08,0.006955788,1.490116e-08,0.0103705,1.490116e-08,1.490116e-08,
	1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.0001336209,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,
	1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.005842602,1.490116e-08,0.03062162,1.490116e-08,1.490116e-08,0.02512913,
	1.490116e-08,0.005845255,0.02964625,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.01362725,0.00318443,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.02585323,1.490116e-08,1.490116e-08,
	1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.006876822,39.75011,0.0495586,1.490116e-08,1.490116e-08,0.01761491,0.02573231,
	1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.01040253,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.007306871,
	0.0003473068,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.009196998,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.01817766,
	0.001553622,3.720721e-06,89.98467,462.9543,210.3743,1.490116e-08,1.490116e-08,0.01362846,1.490116e-08,159.0117,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,
	0.008644248,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.008629846,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,0.001467478,573.9009,1.490116e-08,1.490116e-08,0.0001304165,1.490116e-08,1.490116e-08,
	1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,
	1.490116e-08,0.005418747,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08,1.490116e-08)

genout_m2=GenMatch(fit.func=lower.bound, Tr=college, X=Xmat, BalanceMatrix=out, estimand='ATC', M = 3, pop.size=1, max.generations=1, wait.generations=1, hard.generation.limit=F, starting.values=starts, nboots=0, ties=T, MemoryMatrix=F)	

1973

mout_m2=Match(Y=yppnscal,Tr=college, X=Xmat, estimand='ATC', M = 3, ties=T, Weight.matrix=genout_m2) 
summary(mout_m2)

matbal_m2 = MatchBalance(college ~ yGPA + yGen + yBlack + yRep+ yKnowledge + yNextSch + pVote + pPersuade + pParticipate2 + pEmploy + pEducHH + pEducW + pHHInc + pOwnHome + pRep  + pKnowledge, match.out = mout_m2,nboots=1000)
matbal_all2=MatchBalance(college ~ out, match.out = mout_m2)
mb2=percent.bal(matbal_all2)
mb2[[1]] # 0.4084507 :: 0.9014085

# Sensitivity Test

gamma_m2=hl.rbound(mout_m2, gamma=c(2,3,4,5), pr=.01, Y=yppnscal, paired=TRUE)

1982

mout_m5=Match(Y=y1982yppnscal[!is.na(y1982yppnscal)],Tr=college[!is.na(y1982yppnscal)], X=Xmat[!is.na(y1982yppnscal),], estimand='ATC', M = 3, ties=T, Weight.matrix=genout_m2) 
summary(mout_m5)

matbal_m5 = MatchBalance(college ~ yGPA + yGen + yBlack + yRep+ yKnowledge + yNextSch + pVote + pPersuade + pParticipate2 + pEmploy + pEducHH + pEducW + pHHInc + pOwnHome + pRep  + pKnowledge, match.out = mout_m5,nboots=1000)
matbal_all5=MatchBalance(college ~ out, match.out = mout_m5)
mb5=percent.bal(matbal_all5)
mb5[[1]] # 0.4084507 :: 0.7380282

# Sensitivity Test

gamma_m5=hl.rbound(mout_m5, gamma=c(2,3,4,5), pr=.01, Y=y1982yppnscal[!is.na(y1982yppnscal)], paired=TRUE)
  

#END
# Out:
# The following objects are masked from data_rep (pos = 4):
#
#     college, Control_ID, interviewid, lottery, pActFrq, pButton,
#     pCCamp, pChurchOrg, pCivicOrg, pCLOrg, pClubLev, pCourt, pEducHH,
#     pEducW, pEmploy, pFarmGr, pFDR, pFInc, pFPlans, pFratOrg, pGen,
#     pGLuck, pGovern, pGovt4All, pGovtCrook, pGovtOpinion, pGovtSmart,
#     pGovtWaste, pGPHighSchoolPlacebo, pHHCollege, pHHCollegePlacebo,
#     pHHInc, pInfClub, pKnowledge, pLifeWish, pMagazine, pMChange,
#     pMednInc, pMiscClub, pMoney, pNeighClub, pNewspaper, pOthAct,
#     pOthFair, pOthHelp, pOwnHome, pParticipate1, pParticipate2,
#     pPersuade, pPID, pPolClub, pProOrg, pRace, pRadio, pRally, pRep,
#     pSenate, pSPID, pSportClub, pStrOpinion, pTito, pTrGovt, pTrOthers,
#     pTV, pVote, pWCollege, pWinArg, pWomenClub, Treatment_ID,
#     y1973Busing, y1973ChurchAttend, y1973CollegeDegree,
#     y1973CollegeYears, y1973CurrentCollege, y1973CurrentSituation,
#     y1973Drafted, y1973FutureSituation, y1973GovChange,
#     y1973GovtEfficacy, y1973GovtNoSay, y1973HelpMinority, y1973HHInc,
#     y1973Ideology, y1973IncSelf, y1973Knowledge, y1973Luck,
#     y1973Married, y1973Military, y1973Newspaper, y1973NoEmployers,
#     y1973NoResidences, y1973OwnHome, y1973PartyID, y1973PubAffairs,
#     y1973SureAboutLife, y1973ThermBlack, y1973ThermDems,
#     y1973ThermMcgovern, y1973ThermMilitary, y1973ThermNixon,
#     y1973ThermRadical, y1973ThermRep, y1973ThermWhite, y1973Trust,
#     y1973Unemployed, y1973VietnamApprove, y1973VietnamRight,
#     y1973VoteMcgovern, y1973VoteNixon, y1982button, y1982College,
#     y1982communicate, y1982community, y1982demonstrate, y1982HHInc,
#     y1982IncSelf, y1982meeting, y1982money, y1982other, y1982vote76,
#     y1982vote80, y1982yppnscal, yAdultTalk, yBlack, ybutton, yCCamp,
#     yClubLev, ycommunicate, ycommunity, yCourt, yCynic, ydemonstrate,
#     yEgoA, yEgoB, yFamTalk, yFDR, yFPlans, yFrTalk, yGen, yGLuck,
#     yGovern, yGovt4All, yGovtCrook, yGovtOpinion, yGovtSmart,
#     yGovtWaste, yGPA, yHobby, yKnowledge, yLifeWish, yMagazine,
#     yMChange, ymeeting, yMiscClub, ymoney, yNeighClub, yNewspaper,
#     yNextSch, yOccClub, yother, yOthFair, yOthHelp, yPhone, yPID,
#     yppnscal, yPubAff, yRace, yRadio, yRelClub, yRep, ySchClub,
#     ySchOfficer, ySchPublish, ySenate, ySPID, yStrOpinion, yTito,
#     yTrGovt, yTrOthers, yTrust, yTV, yvote, yWhite, yWinArg, yYouthOrg
#
# The following objects are masked from factors (pos = 4):
#
#     pActFrqZ, pButtonZ, pCCampZ, pChurchOrgZ, pCivicOrgZ, pCLOrgZ,
#     pClubLevZ, pCourtZ, pEducHHZ, pEducWZ, pEmployZ, pFarmGrZ, pFDRZ,
#     pFIncZ, pFPlansZ, pFratOrgZ, pGenZ, pGLuckZ, pGovernZ, pGovt4AllZ,
#     pGovtCrookZ, pGovtOpinionZ, pGovtSmartZ, pGovtWasteZ, pHHCollegeZ,
#     pHHIncZ, pInfClubZ, pKnowledgeZ, pLifeWishZ, pMagazineZ, pMChangeZ,
#     pMednIncZ, pMiscClubZ, pMoneyZ, pNeighClubZ, pNewspaperZ, pOthActZ,
#     pOthFairZ, pOthHelpZ, pOwnHomeZ, pParticipate1Z, pParticipate2Z,
#     pPersuadeZ, pPIDZ, pPolClubZ, pProOrgZ, pRaceZ, pRadioZ, pRallyZ,
#     pSenateZ, pSPIDZ, pSportClubZ, pStrOpinionZ, pTitoZ, pTrGovtZ,
#     pTrOthersZ, pTVZ, pVoteZ, pWCollegeZ, pWinArgZ, pWomenClubZ,
#     yAdultTalkZ, yCCampZ, yClubLevZ, yCourtZ, yCynicZ, yEgoAZ, yEgoBZ,
#     yFamTalkZ, yFDRZ, yFPlansZ, yFrTalkZ, yGenZ, yGLuckZ, yGovernZ,
#     yGovt4AllZ, yGovtCrookZ, yGovtOpinionZ, yGovtSmartZ, yGovtWasteZ,
#     yGPAZ, yHobbyZ, yKnowledgeZ, yLifeWishZ, yMagazineZ, yMChangeZ,
#     yMiscClubZ, yNeighClubZ, yNewspaperZ, yNextSchZ, yOccClubZ,
#     yOthFairZ, yOthHelpZ, yPhoneZ, yPIDZ, yPubAffZ, yRaceZ, yRadioZ,
#     yRelClubZ, ySchClubZ, ySchOfficerZ, ySchPublishZ, ySenateZ, ySPIDZ,
#     yStrOpinionZ, yTitoZ, yTrGovtZ, yTrOthersZ, yTrustZ, yTVZ,
#     yWinArgZ, yYouthOrgZ
# [1] 0.3605634
# Warning message in rgenoud::genoud(genoudfunc, nvars = nvars, starting.values = starting.values, :
# "you specified lexical = TRUE but the function returns a scalar"
# Fri Apr 22 11:22:59 2022
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+03
#  0.000000e+00   <=  X2   <=    1.000000e+03
#  0.000000e+00   <=  X3   <=    1.000000e+03
#  0.000000e+00   <=  X4   <=    1.000000e+03
#  0.000000e+00   <=  X5   <=    1.000000e+03
#  0.000000e+00   <=  X6   <=    1.000000e+03
#  0.000000e+00   <=  X7   <=    1.000000e+03
#  0.000000e+00   <=  X8   <=    1.000000e+03
#  0.000000e+00   <=  X9   <=    1.000000e+03
#  0.000000e+00   <=  X10  <=    1.000000e+03
#  0.000000e+00   <=  X11  <=    1.000000e+03
#  0.000000e+00   <=  X12  <=    1.000000e+03
#  0.000000e+00   <=  X13  <=    1.000000e+03
#  0.000000e+00   <=  X14  <=    1.000000e+03
#  0.000000e+00   <=  X15  <=    1.000000e+03
#  0.000000e+00   <=  X16  <=    1.000000e+03
#  0.000000e+00   <=  X17  <=    1.000000e+03
#  0.000000e+00   <=  X18  <=    1.000000e+03
#  0.000000e+00   <=  X19  <=    1.000000e+03
#  0.000000e+00   <=  X20  <=    1.000000e+03
#  0.000000e+00   <=  X21  <=    1.000000e+03
#  0.000000e+00   <=  X22  <=    1.000000e+03
#  0.000000e+00   <=  X23  <=    1.000000e+03
#  0.000000e+00   <=  X24  <=    1.000000e+03
#  0.000000e+00   <=  X25  <=    1.000000e+03
#  0.000000e+00   <=  X26  <=    1.000000e+03
#  0.000000e+00   <=  X27  <=    1.000000e+03
#  0.000000e+00   <=  X28  <=    1.000000e+03
#  0.000000e+00   <=  X29  <=    1.000000e+03
#  0.000000e+00   <=  X30  <=    1.000000e+03
#  0.000000e+00   <=  X31  <=    1.000000e+03
#  0.000000e+00   <=  X32  <=    1.000000e+03
#  0.000000e+00   <=  X33  <=    1.000000e+03
#  0.000000e+00   <=  X34  <=    1.000000e+03
#  0.000000e+00   <=  X35  <=    1.000000e+03
#  0.000000e+00   <=  X36  <=    1.000000e+03
#  0.000000e+00   <=  X37  <=    1.000000e+03
#  0.000000e+00   <=  X38  <=    1.000000e+03
#  0.000000e+00   <=  X39  <=    1.000000e+03
#  0.000000e+00   <=  X40  <=    1.000000e+03
#  0.000000e+00   <=  X41  <=    1.000000e+03
#  0.000000e+00   <=  X42  <=    1.000000e+03
#  0.000000e+00   <=  X43  <=    1.000000e+03
#  0.000000e+00   <=  X44  <=    1.000000e+03
#  0.000000e+00   <=  X45  <=    1.000000e+03
#  0.000000e+00   <=  X46  <=    1.000000e+03
#  0.000000e+00   <=  X47  <=    1.000000e+03
#  0.000000e+00   <=  X48  <=    1.000000e+03
#  0.000000e+00   <=  X49  <=    1.000000e+03
#  0.000000e+00   <=  X50  <=    1.000000e+03
#  0.000000e+00   <=  X51  <=    1.000000e+03
#  0.000000e+00   <=  X52  <=    1.000000e+03
#  0.000000e+00   <=  X53  <=    1.000000e+03
#  0.000000e+00   <=  X54  <=    1.000000e+03
#  0.000000e+00   <=  X55  <=    1.000000e+03
#  0.000000e+00   <=  X56  <=    1.000000e+03
#  0.000000e+00   <=  X57  <=    1.000000e+03
#  0.000000e+00   <=  X58  <=    1.000000e+03
#  0.000000e+00   <=  X59  <=    1.000000e+03
#  0.000000e+00   <=  X60  <=    1.000000e+03
#  0.000000e+00   <=  X61  <=    1.000000e+03
#  0.000000e+00   <=  X62  <=    1.000000e+03
#  0.000000e+00   <=  X63  <=    1.000000e+03
#  0.000000e+00   <=  X64  <=    1.000000e+03
#  0.000000e+00   <=  X65  <=    1.000000e+03
#  0.000000e+00   <=  X66  <=    1.000000e+03
#  0.000000e+00   <=  X67  <=    1.000000e+03
#  0.000000e+00   <=  X68  <=    1.000000e+03
#  0.000000e+00   <=  X69  <=    1.000000e+03
#  0.000000e+00   <=  X70  <=    1.000000e+03
#  0.000000e+00   <=  X71  <=    1.000000e+03
#  0.000000e+00   <=  X72  <=    1.000000e+03
#  0.000000e+00   <=  X73  <=    1.000000e+03
#  0.000000e+00   <=  X74  <=    1.000000e+03
#  0.000000e+00   <=  X75  <=    1.000000e+03
#  0.000000e+00   <=  X76  <=    1.000000e+03
#  0.000000e+00   <=  X77  <=    1.000000e+03
#  0.000000e+00   <=  X78  <=    1.000000e+03
#  0.000000e+00   <=  X79  <=    1.000000e+03
#  0.000000e+00   <=  X80  <=    1.000000e+03
#  0.000000e+00   <=  X81  <=    1.000000e+03
#  0.000000e+00   <=  X82  <=    1.000000e+03
#  0.000000e+00   <=  X83  <=    1.000000e+03
#  0.000000e+00   <=  X84  <=    1.000000e+03
#  0.000000e+00   <=  X85  <=    1.000000e+03
#  0.000000e+00   <=  X86  <=    1.000000e+03
#  0.000000e+00   <=  X87  <=    1.000000e+03
#  0.000000e+00   <=  X88  <=    1.000000e+03
#  0.000000e+00   <=  X89  <=    1.000000e+03
#  0.000000e+00   <=  X90  <=    1.000000e+03
#  0.000000e+00   <=  X91  <=    1.000000e+03
#  0.000000e+00   <=  X92  <=    1.000000e+03
#  0.000000e+00   <=  X93  <=    1.000000e+03
#  0.000000e+00   <=  X94  <=    1.000000e+03
#  0.000000e+00   <=  X95  <=    1.000000e+03
#  0.000000e+00   <=  X96  <=    1.000000e+03
#  0.000000e+00   <=  X97  <=    1.000000e+03
#  0.000000e+00   <=  X98  <=    1.000000e+03
#  0.000000e+00   <=  X99  <=    1.000000e+03
#  0.000000e+00   <=  X100  <=    1.000000e+03
#  0.000000e+00   <=  X101  <=    1.000000e+03
#  0.000000e+00   <=  X102  <=    1.000000e+03
#  0.000000e+00   <=  X103  <=    1.000000e+03
#  0.000000e+00   <=  X104  <=    1.000000e+03
#  0.000000e+00   <=  X105  <=    1.000000e+03
#  0.000000e+00   <=  X106  <=    1.000000e+03
#  0.000000e+00   <=  X107  <=    1.000000e+03
#  0.000000e+00   <=  X108  <=    1.000000e+03
#  0.000000e+00   <=  X109  <=    1.000000e+03
#  0.000000e+00   <=  X110  <=    1.000000e+03
#  0.000000e+00   <=  X111  <=    1.000000e+03
#  0.000000e+00   <=  X112  <=    1.000000e+03
#  0.000000e+00   <=  X113  <=    1.000000e+03
#  0.000000e+00   <=  X114  <=    1.000000e+03
#  0.000000e+00   <=  X115  <=    1.000000e+03
#  0.000000e+00   <=  X116  <=    1.000000e+03
#  0.000000e+00   <=  X117  <=    1.000000e+03
#  0.000000e+00   <=  X118  <=    1.000000e+03
#  0.000000e+00   <=  X119  <=    1.000000e+03
#  0.000000e+00   <=  X120  <=    1.000000e+03
#  0.000000e+00   <=  X121  <=    1.000000e+03
#  0.000000e+00   <=  X122  <=    1.000000e+03
#  0.000000e+00   <=  X123  <=    1.000000e+03
#  0.000000e+00   <=  X124  <=    1.000000e+03
#  0.000000e+00   <=  X125  <=    1.000000e+03
#  0.000000e+00   <=  X126  <=    1.000000e+03
#  0.000000e+00   <=  X127  <=    1.000000e+03
#  0.000000e+00   <=  X128  <=    1.000000e+03
#  0.000000e+00   <=  X129  <=    1.000000e+03
#  0.000000e+00   <=  X130  <=    1.000000e+03
#  0.000000e+00   <=  X131  <=    1.000000e+03
#  0.000000e+00   <=  X132  <=    1.000000e+03
#  0.000000e+00   <=  X133  <=    1.000000e+03
#  0.000000e+00   <=  X134  <=    1.000000e+03
#  0.000000e+00   <=  X135  <=    1.000000e+03
#  0.000000e+00   <=  X136  <=    1.000000e+03
#  0.000000e+00   <=  X137  <=    1.000000e+03
#  0.000000e+00   <=  X138  <=    1.000000e+03
#  0.000000e+00   <=  X139  <=    1.000000e+03
#  0.000000e+00   <=  X140  <=    1.000000e+03
#  0.000000e+00   <=  X141  <=    1.000000e+03
#  0.000000e+00   <=  X142  <=    1.000000e+03
#  0.000000e+00   <=  X143  <=    1.000000e+03
#  0.000000e+00   <=  X144  <=    1.000000e+03
#  0.000000e+00   <=  X145  <=    1.000000e+03
#  0.000000e+00   <=  X146  <=    1.000000e+03
#  0.000000e+00   <=  X147  <=    1.000000e+03
#  0.000000e+00   <=  X148  <=    1.000000e+03
#  0.000000e+00   <=  X149  <=    1.000000e+03
#  0.000000e+00   <=  X150  <=    1.000000e+03
#  0.000000e+00   <=  X151  <=    1.000000e+03
#  0.000000e+00   <=  X152  <=    1.000000e+03
#  0.000000e+00   <=  X153  <=    1.000000e+03
#  0.000000e+00   <=  X154  <=    1.000000e+03
#  0.000000e+00   <=  X155  <=    1.000000e+03
#  0.000000e+00   <=  X156  <=    1.000000e+03
#  0.000000e+00   <=  X157  <=    1.000000e+03
#  0.000000e+00   <=  X158  <=    1.000000e+03
#  0.000000e+00   <=  X159  <=    1.000000e+03
#  0.000000e+00   <=  X160  <=    1.000000e+03
#  0.000000e+00   <=  X161  <=    1.000000e+03
#  0.000000e+00   <=  X162  <=    1.000000e+03
#  0.000000e+00   <=  X163  <=    1.000000e+03
#  0.000000e+00   <=  X164  <=    1.000000e+03
#  0.000000e+00   <=  X165  <=    1.000000e+03
#  0.000000e+00   <=  X166  <=    1.000000e+03
#  0.000000e+00   <=  X167  <=    1.000000e+03
#  0.000000e+00   <=  X168  <=    1.000000e+03
#  0.000000e+00   <=  X169  <=    1.000000e+03
#  0.000000e+00   <=  X170  <=    1.000000e+03
#  0.000000e+00   <=  X171  <=    1.000000e+03
#  0.000000e+00   <=  X172  <=    1.000000e+03
#  0.000000e+00   <=  X173  <=    1.000000e+03
#  0.000000e+00   <=  X174  <=    1.000000e+03
#  0.000000e+00   <=  X175  <=    1.000000e+03
#  0.000000e+00   <=  X176  <=    1.000000e+03
#  0.000000e+00   <=  X177  <=    1.000000e+03
#  0.000000e+00   <=  X178  <=    1.000000e+03
#  0.000000e+00   <=  X179  <=    1.000000e+03
#  0.000000e+00   <=  X180  <=    1.000000e+03
#  0.000000e+00   <=  X181  <=    1.000000e+03
#  0.000000e+00   <=  X182  <=    1.000000e+03
#  0.000000e+00   <=  X183  <=    1.000000e+03
#  0.000000e+00   <=  X184  <=    1.000000e+03
#  0.000000e+00   <=  X185  <=    1.000000e+03
#  0.000000e+00   <=  X186  <=    1.000000e+03
#  0.000000e+00   <=  X187  <=    1.000000e+03
#  0.000000e+00   <=  X188  <=    1.000000e+03
#  0.000000e+00   <=  X189  <=    1.000000e+03
#  0.000000e+00   <=  X190  <=    1.000000e+03
#  0.000000e+00   <=  X191  <=    1.000000e+03
#  0.000000e+00   <=  X192  <=    1.000000e+03
#  0.000000e+00   <=  X193  <=    1.000000e+03
#  0.000000e+00   <=  X194  <=    1.000000e+03
#  0.000000e+00   <=  X195  <=    1.000000e+03
#  0.000000e+00   <=  X196  <=    1.000000e+03
#  0.000000e+00   <=  X197  <=    1.000000e+03
#  0.000000e+00   <=  X198  <=    1.000000e+03
#  0.000000e+00   <=  X199  <=    1.000000e+03
#  0.000000e+00   <=  X200  <=    1.000000e+03
#  0.000000e+00   <=  X201  <=    1.000000e+03
#  0.000000e+00   <=  X202  <=    1.000000e+03
#  0.000000e+00   <=  X203  <=    1.000000e+03
#  0.000000e+00   <=  X204  <=    1.000000e+03
#  0.000000e+00   <=  X205  <=    1.000000e+03
#  0.000000e+00   <=  X206  <=    1.000000e+03
#  0.000000e+00   <=  X207  <=    1.000000e+03
#  0.000000e+00   <=  X208  <=    1.000000e+03
#  0.000000e+00   <=  X209  <=    1.000000e+03
#  0.000000e+00   <=  X210  <=    1.000000e+03
#  0.000000e+00   <=  X211  <=    1.000000e+03
#  0.000000e+00   <=  X212  <=    1.000000e+03
#  0.000000e+00   <=  X213  <=    1.000000e+03
#  0.000000e+00   <=  X214  <=    1.000000e+03
#  0.000000e+00   <=  X215  <=    1.000000e+03
#  0.000000e+00   <=  X216  <=    1.000000e+03
#  0.000000e+00   <=  X217  <=    1.000000e+03
#  0.000000e+00   <=  X218  <=    1.000000e+03
#  0.000000e+00   <=  X219  <=    1.000000e+03
#  0.000000e+00   <=  X220  <=    1.000000e+03
#  0.000000e+00   <=  X221  <=    1.000000e+03
#  0.000000e+00   <=  X222  <=    1.000000e+03
#  0.000000e+00   <=  X223  <=    1.000000e+03
#  0.000000e+00   <=  X224  <=    1.000000e+03
#  0.000000e+00   <=  X225  <=    1.000000e+03
#  0.000000e+00   <=  X226  <=    1.000000e+03
#  0.000000e+00   <=  X227  <=    1.000000e+03
#  0.000000e+00   <=  X228  <=    1.000000e+03
#  0.000000e+00   <=  X229  <=    1.000000e+03
#  0.000000e+00   <=  X230  <=    1.000000e+03
#  0.000000e+00   <=  X231  <=    1.000000e+03
#  0.000000e+00   <=  X232  <=    1.000000e+03
#  0.000000e+00   <=  X233  <=    1.000000e+03
#  0.000000e+00   <=  X234  <=    1.000000e+03
#  0.000000e+00   <=  X235  <=    1.000000e+03
#  0.000000e+00   <=  X236  <=    1.000000e+03
#  0.000000e+00   <=  X237  <=    1.000000e+03
#  0.000000e+00   <=  X238  <=    1.000000e+03
#  0.000000e+00   <=  X239  <=    1.000000e+03
#  0.000000e+00   <=  X240  <=    1.000000e+03
#  0.000000e+00   <=  X241  <=    1.000000e+03
#  0.000000e+00   <=  X242  <=    1.000000e+03
#  0.000000e+00   <=  X243  <=    1.000000e+03
#  0.000000e+00   <=  X244  <=    1.000000e+03
#  0.000000e+00   <=  X245  <=    1.000000e+03
#  0.000000e+00   <=  X246  <=    1.000000e+03
#  0.000000e+00   <=  X247  <=    1.000000e+03
#  0.000000e+00   <=  X248  <=    1.000000e+03
#  0.000000e+00   <=  X249  <=    1.000000e+03
#  0.000000e+00   <=  X250  <=    1.000000e+03
#  0.000000e+00   <=  X251  <=    1.000000e+03
#  0.000000e+00   <=  X252  <=    1.000000e+03
#  0.000000e+00   <=  X253  <=    1.000000e+03
#  0.000000e+00   <=  X254  <=    1.000000e+03
#  0.000000e+00   <=  X255  <=    1.000000e+03
#  0.000000e+00   <=  X256  <=    1.000000e+03
#  0.000000e+00   <=  X257  <=    1.000000e+03
#  0.000000e+00   <=  X258  <=    1.000000e+03
#  0.000000e+00   <=  X259  <=    1.000000e+03
#  0.000000e+00   <=  X260  <=    1.000000e+03
#  0.000000e+00   <=  X261  <=    1.000000e+03
#  0.000000e+00   <=  X262  <=    1.000000e+03
#  0.000000e+00   <=  X263  <=    1.000000e+03
#  0.000000e+00   <=  X264  <=    1.000000e+03
#  0.000000e+00   <=  X265  <=    1.000000e+03
#  0.000000e+00   <=  X266  <=    1.000000e+03
#  0.000000e+00   <=  X267  <=    1.000000e+03
#  0.000000e+00   <=  X268  <=    1.000000e+03
#  0.000000e+00   <=  X269  <=    1.000000e+03
#  0.000000e+00   <=  X270  <=    1.000000e+03
#  0.000000e+00   <=  X271  <=    1.000000e+03
#  0.000000e+00   <=  X272  <=    1.000000e+03
#  0.000000e+00   <=  X273  <=    1.000000e+03
#  0.000000e+00   <=  X274  <=    1.000000e+03
#  0.000000e+00   <=  X275  <=    1.000000e+03
#  0.000000e+00   <=  X276  <=    1.000000e+03
#  0.000000e+00   <=  X277  <=    1.000000e+03
#  0.000000e+00   <=  X278  <=    1.000000e+03
#  0.000000e+00   <=  X279  <=    1.000000e+03
#  0.000000e+00   <=  X280  <=    1.000000e+03
#  0.000000e+00   <=  X281  <=    1.000000e+03
#  0.000000e+00   <=  X282  <=    1.000000e+03
#  0.000000e+00   <=  X283  <=    1.000000e+03
#  0.000000e+00   <=  X284  <=    1.000000e+03
#  0.000000e+00   <=  X285  <=    1.000000e+03
#  0.000000e+00   <=  X286  <=    1.000000e+03
#  0.000000e+00   <=  X287  <=    1.000000e+03
#  0.000000e+00   <=  X288  <=    1.000000e+03
#  0.000000e+00   <=  X289  <=    1.000000e+03
#  0.000000e+00   <=  X290  <=    1.000000e+03
#  0.000000e+00   <=  X291  <=    1.000000e+03
#  0.000000e+00   <=  X292  <=    1.000000e+03
#  0.000000e+00   <=  X293  <=    1.000000e+03
#  0.000000e+00   <=  X294  <=    1.000000e+03
#  0.000000e+00   <=  X295  <=    1.000000e+03
#  0.000000e+00   <=  X296  <=    1.000000e+03
#  0.000000e+00   <=  X297  <=    1.000000e+03
#  0.000000e+00   <=  X298  <=    1.000000e+03
#  0.000000e+00   <=  X299  <=    1.000000e+03
#  0.000000e+00   <=  X300  <=    1.000000e+03
#  0.000000e+00   <=  X301  <=    1.000000e+03
#  0.000000e+00   <=  X302  <=    1.000000e+03
#  0.000000e+00   <=  X303  <=    1.000000e+03
#  0.000000e+00   <=  X304  <=    1.000000e+03
#  0.000000e+00   <=  X305  <=    1.000000e+03
#  0.000000e+00   <=  X306  <=    1.000000e+03
#  0.000000e+00   <=  X307  <=    1.000000e+03
#  0.000000e+00   <=  X308  <=    1.000000e+03
#  0.000000e+00   <=  X309  <=    1.000000e+03
#  0.000000e+00   <=  X310  <=    1.000000e+03
#  0.000000e+00   <=  X311  <=    1.000000e+03
#  0.000000e+00   <=  X312  <=    1.000000e+03
#  0.000000e+00   <=  X313  <=    1.000000e+03
#  0.000000e+00   <=  X314  <=    1.000000e+03
#  0.000000e+00   <=  X315  <=    1.000000e+03
#  0.000000e+00   <=  X316  <=    1.000000e+03
#  0.000000e+00   <=  X317  <=    1.000000e+03
#  0.000000e+00   <=  X318  <=    1.000000e+03
#  0.000000e+00   <=  X319  <=    1.000000e+03
#  0.000000e+00   <=  X320  <=    1.000000e+03
#  0.000000e+00   <=  X321  <=    1.000000e+03
#  0.000000e+00   <=  X322  <=    1.000000e+03
#  0.000000e+00   <=  X323  <=    1.000000e+03
#  0.000000e+00   <=  X324  <=    1.000000e+03
#  0.000000e+00   <=  X325  <=    1.000000e+03
#  0.000000e+00   <=  X326  <=    1.000000e+03
#  0.000000e+00   <=  X327  <=    1.000000e+03
#  0.000000e+00   <=  X328  <=    1.000000e+03
#  0.000000e+00   <=  X329  <=    1.000000e+03
#  0.000000e+00   <=  X330  <=    1.000000e+03
#  0.000000e+00   <=  X331  <=    1.000000e+03
#  0.000000e+00   <=  X332  <=    1.000000e+03
#  0.000000e+00   <=  X333  <=    1.000000e+03
#  0.000000e+00   <=  X334  <=    1.000000e+03
#  0.000000e+00   <=  X335  <=    1.000000e+03
#  0.000000e+00   <=  X336  <=    1.000000e+03
#  0.000000e+00   <=  X337  <=    1.000000e+03
#  0.000000e+00   <=  X338  <=    1.000000e+03
#  0.000000e+00   <=  X339  <=    1.000000e+03
#  0.000000e+00   <=  X340  <=    1.000000e+03
#  0.000000e+00   <=  X341  <=    1.000000e+03
#  0.000000e+00   <=  X342  <=    1.000000e+03
#  0.000000e+00   <=  X343  <=    1.000000e+03
#  0.000000e+00   <=  X344  <=    1.000000e+03
#  0.000000e+00   <=  X345  <=    1.000000e+03
#  0.000000e+00   <=  X346  <=    1.000000e+03
#  0.000000e+00   <=  X347  <=    1.000000e+03
#  0.000000e+00   <=  X348  <=    1.000000e+03
#  0.000000e+00   <=  X349  <=    1.000000e+03
#  0.000000e+00   <=  X350  <=    1.000000e+03
#  0.000000e+00   <=  X351  <=    1.000000e+03
#  0.000000e+00   <=  X352  <=    1.000000e+03
#  0.000000e+00   <=  X353  <=    1.000000e+03
#  0.000000e+00   <=  X354  <=    1.000000e+03
#  0.000000e+00   <=  X355  <=    1.000000e+03
#  0.000000e+00   <=  X356  <=    1.000000e+03
#  0.000000e+00   <=  X357  <=    1.000000e+03
# NOTE: population size is not an even number
#       increasing population size by 1
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	1
# 	(2) Uniform Mutation.................. 	0
# 	(3) Boundary Mutation................. 	0
# 	(4) Non-Uniform Mutation.............. 	0
# 	(5) Polytope Crossover................ 	0
# 	(6) Simple Crossover.................. 	0
# 	(7) Whole Non-Uniform Mutation........ 	0
# 	(8) Heuristic Crossover............... 	0
# 	(9) Local-Minimum Crossover........... 	0
#
# SOFT Maximum Number of Generations: 1
# Maximum Nonchanging Generations: 1
# Population size       : 2
# Convergence Tolerance: 1.000000e-03
#
# Not Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Using Out of Bounds Individuals.
#
# Minimization Problem.
# [1] 0.3605634
# [1] 0.1971831
# GENERATION: 0 (initializing the population)
# Fitness value... 6.394366e-01
# mean............ 7.211268e-01
# variance........ 6.673279e-03
# var 1:
# best............ 9.999925e+01
# mean............ 4.894717e+02
# variance........ 1.516888e+05
# var 2:
# best............ 1.000053e+02
# mean............ 4.658157e+02
# variance........ 1.338172e+05
# var 3:
# best............ 5.715251e-03
# mean............ 2.460648e+02
# variance........ 6.054509e+04
# var 4:
# best............ 6.408247e-03
# mean............ 2.898609e+02
# variance........ 8.401563e+04
# var 5:
# best............ 2.980232e-08
# mean............ 1.696846e+02
# variance........ 2.879288e+04
# var 6:
# best............ 2.980232e-08
# mean............ 1.497054e+02
# variance........ 2.241169e+04
# var 7:
# best............ 6.262702e-03
# mean............ 3.108879e+02
# variance........ 9.664741e+04
# var 8:
# best............ 8.668285e-03
# mean............ 1.691381e+02
# variance........ 2.860475e+04
# var 9:
# best............ 2.980232e-08
# mean............ 1.488802e+02
# variance........ 2.216531e+04
# var 10:
# best............ 2.887763e-03
# mean............ 9.125209e+01
# variance........ 8.326416e+03
# var 11:
# best............ 2.980232e-08
# mean............ 2.110678e+02
# variance........ 4.454960e+04
# var 12:
# best............ 9.998784e-04
# mean............ 1.778146e+02
# variance........ 3.161767e+04
# var 13:
# best............ 2.455857e-03
# mean............ 4.804140e+02
# variance........ 2.307953e+05
# var 14:
# best............ 3.635949e-03
# mean............ 4.472600e+02
# variance........ 2.000382e+05
# var 15:
# best............ 2.980232e-08
# mean............ 2.141734e+02
# variance........ 4.587024e+04
# var 16:
# best............ 2.980232e-08
# mean............ 3.402962e+02
# variance........ 1.158015e+05
# var 17:
# best............ 2.980232e-08
# mean............ 1.667957e+02
# variance........ 2.782080e+04
# var 18:
# best............ 7.876010e-03
# mean............ 5.348984e+00
# variance........ 2.852744e+01
# var 19:
# best............ 6.441565e-03
# mean............ 5.286580e+00
# variance........ 2.787986e+01
# var 20:
# best............ 6.882892e-03
# mean............ 1.646502e+02
# variance........ 2.710743e+04
# var 21:
# best............ 4.390646e-03
# mean............ 6.807383e+01
# variance........ 4.633449e+03
# var 22:
# best............ 1.944808e-03
# mean............ 3.166161e+02
# variance........ 1.002445e+05
# var 23:
# best............ 5.531695e-03
# mean............ 2.156271e+02
# variance........ 4.649265e+04
# var 24:
# best............ 2.980232e-08
# mean............ 2.932528e+02
# variance........ 8.599722e+04
# var 25:
# best............ 8.536832e-03
# mean............ 3.165444e+02
# variance........ 1.001950e+05
# var 26:
# best............ 6.503187e-03
# mean............ 4.121478e+02
# variance........ 1.698605e+05
# var 27:
# best............ 2.980232e-08
# mean............ 3.858797e+02
# variance........ 1.489031e+05
# var 28:
# best............ 9.334766e-03
# mean............ 1.902220e+02
# variance........ 3.618084e+04
# var 29:
# best............ 2.092330e-03
# mean............ 4.559881e+02
# variance........ 2.079232e+05
# var 30:
# best............ 2.980232e-08
# mean............ 3.442414e+02
# variance........ 1.185022e+05
# var 31:
# best............ 2.980232e-08
# mean............ 1.395384e+02
# variance........ 1.947098e+04
# var 32:
# best............ 2.980232e-08
# mean............ 4.933753e+02
# variance........ 2.434192e+05
# var 33:
# best............ 9.141416e-03
# mean............ 2.771668e+02
# variance........ 7.681636e+04
# var 34:
# best............ 6.710892e-03
# mean............ 3.540694e+02
# variance........ 1.253604e+05
# var 35:
# best............ 2.980232e-08
# mean............ 2.687192e+02
# variance........ 7.220999e+04
# var 36:
# best............ 3.759020e-03
# mean............ 2.193147e+02
# variance........ 4.809727e+04
# var 37:
# best............ 2.980232e-08
# mean............ 2.671681e+02
# variance........ 7.137879e+04
# var 38:
# best............ 2.980232e-08
# mean............ 2.932589e+02
# variance........ 8.600078e+04
# var 39:
# best............ 2.394659e-03
# mean............ 1.493749e+02
# variance........ 2.231215e+04
# var 40:
# best............ 2.549385e-03
# mean............ 4.495926e+02
# variance........ 2.021312e+05
# var 41:
# best............ 2.980232e-08
# mean............ 2.697135e+02
# variance........ 7.274540e+04
# var 42:
# best............ 1.481797e-03
# mean............ 1.783127e+02
# variance........ 3.179489e+04
# var 43:
# best............ 8.610365e-03
# mean............ 5.592342e+01
# variance........ 3.126466e+03
# var 44:
# best............ 2.980232e-08
# mean............ 2.945401e+02
# variance........ 8.675387e+04
# var 45:
# best............ 2.980232e-08
# mean............ 2.021581e+02
# variance........ 4.086789e+04
# var 46:
# best............ 2.980232e-08
# mean............ 4.045258e+02
# variance........ 1.636411e+05
# var 47:
# best............ 9.984436e-03
# mean............ 4.191370e+02
# variance........ 1.756675e+05
# var 48:
# best............ 6.574805e-03
# mean............ 5.596339e+01
# variance........ 3.131165e+03
# var 49:
# best............ 2.360336e-03
# mean............ 3.641839e+02
# variance........ 1.326282e+05
# var 50:
# best............ 8.224860e-03
# mean............ 3.380472e+02
# variance........ 1.142703e+05
# var 51:
# best............ 2.980232e-08
# mean............ 4.528700e+02
# variance........ 2.050912e+05
# var 52:
# best............ 2.980232e-08
# mean............ 1.589484e+02
# variance........ 2.526458e+04
# var 53:
# best............ 4.001202e-03
# mean............ 3.979142e+02
# variance........ 1.583325e+05
# var 54:
# best............ 7.789226e-03
# mean............ 4.252166e+02
# variance........ 1.808025e+05
# var 55:
# best............ 2.980232e-08
# mean............ 5.643569e+00
# variance........ 3.184988e+01
# var 56:
# best............ 8.463702e-03
# mean............ 6.982747e+01
# variance........ 4.874694e+03
# var 57:
# best............ 6.892591e-03
# mean............ 4.213197e+02
# variance........ 1.775045e+05
# var 58:
# best............ 2.980232e-08
# mean............ 4.160194e+02
# variance........ 1.730722e+05
# var 59:
# best............ 3.049413e-03
# mean............ 2.346118e+02
# variance........ 5.504128e+04
# var 60:
# best............ 2.980232e-08
# mean............ 8.091043e+01
# variance........ 6.546498e+03
# var 61:
# best............ 1.608269e-03
# mean............ 3.323705e+02
# variance........ 1.104691e+05
# var 62:
# best............ 4.021724e-03
# mean............ 3.034768e+02
# variance........ 9.209575e+04
# var 63:
# best............ 9.204788e-03
# mean............ 1.215701e+02
# variance........ 1.477706e+04
# var 64:
# best............ 1.364288e-03
# mean............ 3.194293e+02
# variance........ 1.020342e+05
# var 65:
# best............ 1.575996e-03
# mean............ 1.424052e+02
# variance........ 2.027879e+04
# var 66:
# best............ 2.980232e-08
# mean............ 1.380271e+02
# variance........ 1.905148e+04
# var 67:
# best............ 8.038192e-03
# mean............ 3.078752e+02
# variance........ 9.478216e+04
# var 68:
# best............ 2.980232e-08
# mean............ 2.555574e+01
# variance........ 6.530956e+02
# var 69:
# best............ 7.762872e-03
# mean............ 2.010056e+02
# variance........ 4.040013e+04
# var 70:
# best............ 2.980232e-08
# mean............ 4.155806e+02
# variance........ 1.727073e+05
# var 71:
# best............ 5.283075e-03
# mean............ 4.899024e+02
# variance........ 2.399992e+05
# var 72:
# best............ 3.295967e-03
# mean............ 4.314894e+02
# variance........ 1.861802e+05
# var 73:
# best............ 2.980232e-08
# mean............ 2.963644e+02
# variance........ 8.783185e+04
# var 74:
# best............ 2.980232e-08
# mean............ 8.503482e+01
# variance........ 7.230921e+03
# var 75:
# best............ 4.179459e-03
# mean............ 3.449421e+01
# variance........ 1.189562e+03
# var 76:
# best............ 1.736054e+02
# mean............ 1.305076e+02
# variance........ 1.857417e+03
# var 77:
# best............ 2.824357e-03
# mean............ 4.334792e+02
# variance........ 1.879018e+05
# var 78:
# best............ 1.318068e-03
# mean............ 1.708849e+02
# variance........ 2.920119e+04
# var 79:
# best............ 8.916264e-03
# mean............ 9.793994e+01
# variance........ 9.590484e+03
# var 80:
# best............ 2.980232e-08
# mean............ 3.830744e+01
# variance........ 1.467460e+03
# var 81:
# best............ 2.980232e-08
# mean............ 1.288268e+02
# variance........ 1.659633e+04
# var 82:
# best............ 2.980232e-08
# mean............ 2.718803e+02
# variance........ 7.391891e+04
# var 83:
# best............ 2.980232e-08
# mean............ 2.401713e+02
# variance........ 5.768227e+04
# var 84:
# best............ 7.247979e-03
# mean............ 8.255689e+01
# variance........ 6.814443e+03
# var 85:
# best............ 2.980232e-08
# mean............ 1.955664e+02
# variance........ 3.824621e+04
# var 86:
# best............ 6.996465e-03
# mean............ 6.003246e+00
# variance........ 3.595501e+01
# var 87:
# best............ 2.980232e-08
# mean............ 2.155266e+00
# variance........ 4.645169e+00
# var 88:
# best............ 9.502948e-03
# mean............ 6.380528e+01
# variance........ 4.069901e+03
# var 89:
# best............ 2.980232e-08
# mean............ 4.006538e+01
# variance........ 1.605235e+03
# var 90:
# best............ 2.980232e-08
# mean............ 3.445117e+02
# variance........ 1.186883e+05
# var 91:
# best............ 2.980232e-08
# mean............ 6.126655e+01
# variance........ 3.753590e+03
# var 92:
# best............ 2.980232e-08
# mean............ 3.209128e+02
# variance........ 1.029850e+05
# var 93:
# best............ 2.980232e-08
# mean............ 2.940334e+02
# variance........ 8.645566e+04
# var 94:
# best............ 7.643543e-03
# mean............ 2.292459e+02
# variance........ 5.255019e+04
# var 95:
# best............ 2.980232e-08
# mean............ 3.028635e+02
# variance........ 9.172630e+04
# var 96:
# best............ 2.980232e-08
# mean............ 1.448685e+02
# variance........ 2.098688e+04
# var 97:
# best............ 2.980232e-08
# mean............ 9.086911e+01
# variance........ 8.257194e+03
# var 98:
# best............ 2.980232e-08
# mean............ 1.979299e+02
# variance........ 3.917624e+04
# var 99:
# best............ 2.980232e-08
# mean............ 2.589434e+02
# variance........ 6.705170e+04
# var 100:
# best............ 4.981017e-03
# mean............ 4.832798e+02
# variance........ 2.335545e+05
# var 101:
# best............ 1.327190e-04
# mean............ 1.976902e+02
# variance........ 3.908137e+04
# var 102:
# best............ 2.599750e-03
# mean............ 1.688593e+02
# variance........ 2.851257e+04
# var 103:
# best............ 7.494614e-03
# mean............ 3.361110e+02
# variance........ 1.129655e+05
# var 104:
# best............ 8.557601e+02
# mean............ 5.118901e+02
# variance........ 1.182466e+05
# var 105:
# best............ 3.140685e-03
# mean............ 1.007861e+02
# variance........ 1.015720e+04
# var 106:
# best............ 2.980232e-08
# mean............ 1.727570e+02
# variance........ 2.984498e+04
# var 107:
# best............ 2.980232e-08
# mean............ 1.959622e+02
# variance........ 3.840118e+04
# var 108:
# best............ 2.980232e-08
# mean............ 4.188422e+02
# variance........ 1.754288e+05
# var 109:
# best............ 5.202841e-03
# mean............ 3.410115e+02
# variance........ 1.162853e+05
# var 110:
# best............ 2.980232e-08
# mean............ 4.964732e+02
# variance........ 2.464856e+05
# var 111:
# best............ 9.273753e-03
# mean............ 1.047890e+02
# variance........ 1.097880e+04
# var 112:
# best............ 2.980232e-08
# mean............ 1.365957e+02
# variance........ 1.865839e+04
# var 113:
# best............ 1.418590e-03
# mean............ 2.647545e+02
# variance........ 7.009420e+04
# var 114:
# best............ 2.980232e-08
# mean............ 3.524319e+02
# variance........ 1.242082e+05
# var 115:
# best............ 2.784641e-03
# mean............ 2.920912e+01
# variance........ 8.530101e+02
# var 116:
# best............ 8.928815e-03
# mean............ 2.869624e+02
# variance........ 8.234230e+04
# var 117:
# best............ 2.980232e-08
# mean............ 1.626029e+02
# variance........ 2.643971e+04
# var 118:
# best............ 2.980232e-08
# mean............ 4.900678e+02
# variance........ 2.401664e+05
# var 119:
# best............ 5.609324e-03
# mean............ 4.720944e+02
# variance........ 2.228678e+05
# var 120:
# best............ 2.980232e-08
# mean............ 3.989444e+02
# variance........ 1.591566e+05
# var 121:
# best............ 7.712388e-03
# mean............ 2.625471e+02
# variance........ 6.892695e+04
# var 122:
# best............ 2.980232e-08
# mean............ 3.274870e+02
# variance........ 1.072477e+05
# var 123:
# best............ 2.980232e-08
# mean............ 4.090071e+02
# variance........ 1.672868e+05
# var 124:
# best............ 2.980232e-08
# mean............ 2.705682e+02
# variance........ 7.320713e+04
# var 125:
# best............ 2.980232e-08
# mean............ 2.213420e+02
# variance........ 4.899228e+04
# var 126:
# best............ 1.323451e-03
# mean............ 3.288597e+02
# variance........ 1.081479e+05
# var 127:
# best............ 4.780747e-03
# mean............ 2.551710e+02
# variance........ 6.510978e+04
# var 128:
# best............ 1.246533e-03
# mean............ 4.923818e+02
# variance........ 2.424386e+05
# var 129:
# best............ 2.980232e-08
# mean............ 4.871712e+02
# variance........ 2.373358e+05
# var 130:
# best............ 8.068434e-03
# mean............ 9.052901e+01
# variance........ 8.194041e+03
# var 131:
# best............ 2.980232e-08
# mean............ 4.018572e+02
# variance........ 1.614892e+05
# var 132:
# best............ 2.980232e-08
# mean............ 2.070186e+02
# variance........ 4.285669e+04
# var 133:
# best............ 1.275443e-03
# mean............ 2.707811e+01
# variance........ 7.331547e+02
# var 134:
# best............ 3.073698e-03
# mean............ 8.921562e+01
# variance........ 7.958879e+03
# var 135:
# best............ 3.277063e-03
# mean............ 4.406174e+02
# variance........ 1.941408e+05
# var 136:
# best............ 2.980232e-08
# mean............ 3.511918e+02
# variance........ 1.233357e+05
# var 137:
# best............ 2.980232e-08
# mean............ 2.972638e+02
# variance........ 8.836578e+04
# var 138:
# best............ 2.980232e-08
# mean............ 1.504381e+02
# variance........ 2.263161e+04
# var 139:
# best............ 4.064664e-03
# mean............ 3.909045e+02
# variance........ 1.528032e+05
# var 140:
# best............ 8.520083e-03
# mean............ 3.470053e+02
# variance........ 1.204068e+05
# var 141:
# best............ 2.980232e-08
# mean............ 4.950529e+02
# variance........ 2.450774e+05
# var 142:
# best............ 6.505253e-03
# mean............ 4.389107e+02
# variance........ 1.926369e+05
# var 143:
# best............ 5.767007e-03
# mean............ 4.573964e+02
# variance........ 2.092062e+05
# var 144:
# best............ 6.511250e-03
# mean............ 1.768845e+02
# variance........ 3.128581e+04
# var 145:
# best............ 2.980232e-08
# mean............ 1.404646e+02
# variance........ 1.973029e+04
# var 146:
# best............ 2.980232e-08
# mean............ 3.454005e+00
# variance........ 1.193015e+01
# var 147:
# best............ 2.980232e-08
# mean............ 2.414001e+02
# variance........ 5.827399e+04
# var 148:
# best............ 2.980232e-08
# mean............ 2.620805e+02
# variance........ 6.868621e+04
# var 149:
# best............ 4.590578e-03
# mean............ 5.624127e+01
# variance........ 3.162564e+03
# var 150:
# best............ 5.835394e-03
# mean............ 4.682932e+02
# variance........ 2.192930e+05
# var 151:
# best............ 2.980232e-08
# mean............ 5.649385e+01
# variance........ 3.191555e+03
# var 152:
# best............ 2.980232e-08
# mean............ 2.701122e+02
# variance........ 7.296060e+04
# var 153:
# best............ 2.980232e-08
# mean............ 3.388097e+02
# variance........ 1.147920e+05
# var 154:
# best............ 3.976639e-03
# mean............ 4.258222e+02
# variance........ 1.813212e+05
# var 155:
# best............ 2.980232e-08
# mean............ 4.281462e+01
# variance........ 1.833091e+03
# var 156:
# best............ 2.980232e-08
# mean............ 2.017470e+02
# variance........ 4.070187e+04
# var 157:
# best............ 2.980232e-08
# mean............ 4.934109e+02
# variance........ 2.434543e+05
# var 158:
# best............ 4.423570e-03
# mean............ 3.333439e+02
# variance........ 1.111152e+05
# var 159:
# best............ 2.980232e-08
# mean............ 1.614602e+02
# variance........ 2.606940e+04
# var 160:
# best............ 1.809476e-04
# mean............ 1.825599e+02
# variance........ 3.332807e+04
# var 161:
# best............ 2.980232e-08
# mean............ 2.638697e+01
# variance........ 6.962722e+02
# var 162:
# best............ 2.980232e-08
# mean............ 5.709063e+01
# variance........ 3.259340e+03
# var 163:
# best............ 4.345980e-03
# mean............ 1.774472e+02
# variance........ 3.148596e+04
# var 164:
# best............ 4.373333e-03
# mean............ 3.628621e+02
# variance........ 1.316657e+05
# var 165:
# best............ 2.980232e-08
# mean............ 2.905658e+02
# variance........ 8.442849e+04
# var 166:
# best............ 1.005735e-03
# mean............ 6.623642e+01
# variance........ 4.387131e+03
# var 167:
# best............ 9.737443e-03
# mean............ 3.399756e+02
# variance........ 1.155768e+05
# var 168:
# best............ 2.980232e-08
# mean............ 5.564747e+01
# variance........ 3.096641e+03
# var 169:
# best............ 2.980232e-08
# mean............ 4.343047e+02
# variance........ 1.886206e+05
# var 170:
# best............ 2.011738e-03
# mean............ 7.821572e+01
# variance........ 6.117384e+03
# var 171:
# best............ 2.980232e-08
# mean............ 2.635421e+02
# variance........ 6.945443e+04
# var 172:
# best............ 6.726748e-03
# mean............ 1.706179e+02
# variance........ 2.910819e+04
# var 173:
# best............ 2.980232e-08
# mean............ 3.981633e+02
# variance........ 1.585340e+05
# var 174:
# best............ 2.980232e-08
# mean............ 4.217391e+02
# variance........ 1.778639e+05
# var 175:
# best............ 2.980232e-08
# mean............ 3.029828e+02
# variance........ 9.179860e+04
# var 176:
# best............ 2.980232e-08
# mean............ 1.486533e+02
# variance........ 2.209781e+04
# var 177:
# best............ 2.980232e-08
# mean............ 4.542096e+02
# variance........ 2.063064e+05
# var 178:
# best............ 2.980232e-08
# mean............ 3.225817e+02
# variance........ 1.040589e+05
# var 179:
# best............ 5.586700e-03
# mean............ 1.505480e+02
# variance........ 2.266303e+04
# var 180:
# best............ 4.269455e+01
# mean............ 5.211502e+02
# variance........ 2.289198e+05
# var 181:
# best............ 2.980232e-08
# mean............ 1.530901e+02
# variance........ 2.343658e+04
# var 182:
# best............ 1.419610e-04
# mean............ 3.986483e+02
# variance........ 1.589204e+05
# var 183:
# best............ 2.980232e-08
# mean............ 9.904290e+01
# variance........ 9.809496e+03
# var 184:
# best............ 2.980232e-08
# mean............ 3.024012e+02
# variance........ 9.144651e+04
# var 185:
# best............ 2.980232e-08
# mean............ 9.708397e+01
# variance........ 9.425298e+03
# var 186:
# best............ 2.980232e-08
# mean............ 3.294148e+02
# variance........ 1.085141e+05
# var 187:
# best............ 2.980232e-08
# mean............ 2.375206e+02
# variance........ 5.641602e+04
# var 188:
# best............ 1.291604e-03
# mean............ 2.096528e+02
# variance........ 4.395376e+04
# var 189:
# best............ 7.333195e-03
# mean............ 4.601848e+02
# variance........ 2.117633e+05
# var 190:
# best............ 2.980232e-08
# mean............ 4.677391e+02
# variance........ 2.187799e+05
# var 191:
# best............ 8.610143e-03
# mean............ 4.903377e+02
# variance........ 2.404226e+05
# var 192:
# best............ 7.476773e-04
# mean............ 2.306151e+02
# variance........ 5.318299e+04
# var 193:
# best............ 2.980232e-08
# mean............ 1.228681e+02
# variance........ 1.509658e+04
# var 194:
# best............ 2.980232e-08
# mean............ 1.656601e+02
# variance........ 2.744326e+04
# var 195:
# best............ 4.024254e-03
# mean............ 3.219302e+02
# variance........ 1.036364e+05
# var 196:
# best............ 4.522020e-03
# mean............ 4.042907e+02
# variance........ 1.634473e+05
# var 197:
# best............ 1.858119e-03
# mean............ 2.594657e+02
# variance........ 6.732151e+04
# var 198:
# best............ 2.980232e-08
# mean............ 4.763244e+02
# variance........ 2.268849e+05
# var 199:
# best............ 2.980232e-08
# mean............ 4.759763e+02
# variance........ 2.265535e+05
# var 200:
# best............ 2.980232e-08
# mean............ 7.932063e+01
# variance........ 6.291763e+03
# var 201:
# best............ 2.980232e-08
# mean............ 6.095845e+01
# variance........ 3.715933e+03
# var 202:
# best............ 9.335303e-03
# mean............ 1.216252e+02
# variance........ 1.479042e+04
# var 203:
# best............ 2.980232e-08
# mean............ 6.388073e+01
# variance........ 4.080748e+03
# var 204:
# best............ 2.980232e-08
# mean............ 9.202564e+01
# variance........ 8.468718e+03
# var 205:
# best............ 2.980232e-08
# mean............ 1.191141e+02
# variance........ 1.418816e+04
# var 206:
# best............ 2.980232e-08
# mean............ 1.547652e+02
# variance........ 2.395227e+04
# var 207:
# best............ 2.980232e-08
# mean............ 7.170948e+01
# variance........ 5.142250e+03
# var 208:
# best............ 2.980232e-08
# mean............ 4.252796e+02
# variance........ 1.808627e+05
# var 209:
# best............ 2.980232e-08
# mean............ 1.458477e+02
# variance........ 2.127155e+04
# var 210:
# best............ 7.920756e-03
# mean............ 4.086255e+02
# variance........ 1.669684e+05
# var 211:
# best............ 2.980232e-08
# mean............ 2.117944e+02
# variance........ 4.485687e+04
# var 212:
# best............ 1.533510e-03
# mean............ 1.275181e+01
# variance........ 1.625695e+02
# var 213:
# best............ 6.578747e-03
# mean............ 3.448415e+01
# variance........ 1.188703e+03
# var 214:
# best............ 2.980232e-08
# mean............ 1.197506e+02
# variance........ 1.434022e+04
# var 215:
# best............ 2.980232e-08
# mean............ 1.268167e+02
# variance........ 1.608248e+04
# var 216:
# best............ 2.980232e-08
# mean............ 7.724076e+01
# variance........ 5.966135e+03
# var 217:
# best............ 3.463541e-03
# mean............ 3.458052e+02
# variance........ 1.195788e+05
# var 218:
# best............ 2.980232e-08
# mean............ 1.276153e+01
# variance........ 1.628567e+02
# var 219:
# best............ 2.980232e-08
# mean............ 1.879318e+02
# variance........ 3.531837e+04
# var 220:
# best............ 2.980232e-08
# mean............ 3.628505e+00
# variance........ 1.316605e+01
# var 221:
# best............ 6.034420e+02
# mean............ 4.800321e+02
# variance........ 1.523001e+04
# var 222:
# best............ 1.144914e-03
# mean............ 2.949934e+02
# variance........ 8.702043e+04
# var 223:
# best............ 7.914557e-03
# mean............ 5.488632e+01
# variance........ 3.011639e+03
# var 224:
# best............ 2.980232e-08
# mean............ 1.429551e+02
# variance........ 2.043617e+04
# var 225:
# best............ 2.980232e-08
# mean............ 3.951655e+02
# variance........ 1.561558e+05
# var 226:
# best............ 3.372544e-03
# mean............ 4.753850e+02
# variance........ 2.259877e+05
# var 227:
# best............ 7.569384e-03
# mean............ 3.254045e+02
# variance........ 1.058831e+05
# var 228:
# best............ 4.901839e-03
# mean............ 7.690574e+01
# variance........ 5.913739e+03
# var 229:
# best............ 2.980232e-08
# mean............ 1.458045e+02
# variance........ 2.125897e+04
# var 230:
# best............ 2.980232e-08
# mean............ 2.722526e+02
# variance........ 7.412148e+04
# var 231:
# best............ 8.925979e-04
# mean............ 4.342115e+02
# variance........ 1.885389e+05
# var 232:
# best............ 2.980232e-08
# mean............ 3.730323e+02
# variance........ 1.391531e+05
# var 233:
# best............ 5.461286e-03
# mean............ 4.966148e+02
# variance........ 2.466208e+05
# var 234:
# best............ 8.944928e-03
# mean............ 2.677361e+02
# variance........ 7.167781e+04
# var 235:
# best............ 9.883558e-04
# mean............ 2.599810e+02
# variance........ 6.758963e+04
# var 236:
# best............ 3.052224e-03
# mean............ 2.665422e+02
# variance........ 7.104309e+04
# var 237:
# best............ 3.033079e-03
# mean............ 2.297092e+02
# variance........ 5.276495e+04
# var 238:
# best............ 2.980232e-08
# mean............ 1.022333e+02
# variance........ 1.045165e+04
# var 239:
# best............ 8.314635e-03
# mean............ 4.706333e+02
# variance........ 2.214879e+05
# var 240:
# best............ 3.773529e-04
# mean............ 6.770181e+01
# variance........ 4.583484e+03
# var 241:
# best............ 2.980232e-08
# mean............ 3.339299e+02
# variance........ 1.115092e+05
# var 242:
# best............ 2.980232e-08
# mean............ 2.546810e+02
# variance........ 6.486241e+04
# var 243:
# best............ 9.716536e-03
# mean............ 4.511279e+02
# variance........ 2.035076e+05
# var 244:
# best............ 2.884406e+02
# mean............ 3.216395e+02
# variance........ 1.102164e+03
# var 245:
# best............ 2.980232e-08
# mean............ 1.327856e+02
# variance........ 1.763202e+04
# var 246:
# best............ 2.980232e-08
# mean............ 7.249756e+01
# variance........ 5.255896e+03
# var 247:
# best............ 2.980232e-08
# mean............ 4.375557e+02
# variance........ 1.914550e+05
# var 248:
# best............ 2.980232e-08
# mean............ 2.570510e+02
# variance........ 6.607522e+04
# var 249:
# best............ 8.213271e-03
# mean............ 9.576960e+01
# variance........ 9.170243e+03
# var 250:
# best............ 6.999430e+01
# mean............ 5.652618e+01
# variance........ 1.813904e+02
# var 251:
# best............ 2.980232e-08
# mean............ 2.463919e+01
# variance........ 6.070898e+02
# var 252:
# best............ 2.875351e-03
# mean............ 2.023170e+02
# variance........ 4.093100e+04
# var 253:
# best............ 9.604130e-03
# mean............ 4.866294e+02
# variance........ 2.367988e+05
# var 254:
# best............ 7.875248e-03
# mean............ 3.501708e+02
# variance........ 1.226141e+05
# var 255:
# best............ 5.444037e-03
# mean............ 2.829963e+02
# variance........ 8.008383e+04
# var 256:
# best............ 2.980232e-08
# mean............ 3.292851e+02
# variance........ 1.084287e+05
# var 257:
# best............ 3.010958e-03
# mean............ 2.427177e+02
# variance........ 5.891040e+04
# var 258:
# best............ 2.980232e-08
# mean............ 4.365742e+02
# variance........ 1.905971e+05
# var 259:
# best............ 2.980232e-08
# mean............ 2.251002e+02
# variance........ 5.067009e+04
# var 260:
# best............ 2.980232e-08
# mean............ 3.497076e+01
# variance........ 1.222954e+03
# var 261:
# best............ 2.980232e-08
# mean............ 1.469975e+02
# variance........ 2.160827e+04
# var 262:
# best............ 6.345055e-03
# mean............ 2.557206e+02
# variance........ 6.538978e+04
# var 263:
# best............ 2.980232e-08
# mean............ 5.808296e+01
# variance........ 3.373630e+03
# var 264:
# best............ 5.951712e-03
# mean............ 2.036611e+02
# variance........ 4.147543e+04
# var 265:
# best............ 8.675600e-03
# mean............ 4.580628e+02
# variance........ 2.098136e+05
# var 266:
# best............ 2.980232e-08
# mean............ 4.058988e+02
# variance........ 1.647538e+05
# var 267:
# best............ 2.980232e-08
# mean............ 4.678920e+02
# variance........ 2.189229e+05
# var 268:
# best............ 3.141093e-04
# mean............ 3.875807e+02
# variance........ 1.502186e+05
# var 269:
# best............ 2.980232e-08
# mean............ 6.584758e+01
# variance........ 4.335904e+03
# var 270:
# best............ 2.980232e-08
# mean............ 4.699691e+02
# variance........ 2.208710e+05
# var 271:
# best............ 9.148151e-03
# mean............ 9.833457e+01
# variance........ 9.667889e+03
# var 272:
# best............ 4.543724e-03
# ...
#
#
# ***** (V332) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.062267 	 	   0.070035
# mean control..........   0.093126 	 	   0.077128
# std mean diff.........    -12.763 	 	    -2.7753
#
# mean raw eQQ diff.....   0.031042 	 	  0.0070922
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.01543 	 	  0.0035461
# med  eCDF diff........    0.01543 	 	  0.0035461
# max  eCDF diff........    0.03086 	 	  0.0070922
#
# var ratio (Tr/Co).....     0.6907 	 	    0.91502
# T-test p-value........   0.056223 	 	    0.70243
#
#
# ***** (V333) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.063512 	 	    0.11348
# mean control..........    0.11308 	 	   0.074468
# std mean diff.........    -20.313 	 	     12.282
#
# mean raw eQQ diff.....    0.04878 	 	   0.039007
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.024785 	 	   0.019504
# med  eCDF diff........   0.024785 	 	   0.019504
# max  eCDF diff........    0.04957 	 	   0.039007
#
# var ratio (Tr/Co).....    0.59246 	 	     1.4596
# T-test p-value........  0.0041391 	 	    0.06067
#
#
# ***** (V334) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.10212 	 	    0.12057
# mean control..........    0.13525 	 	    0.10106
# std mean diff.........    -10.937 	 	     5.9816
#
# mean raw eQQ diff.....   0.033259 	 	   0.019504
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.016569 	 	  0.0097518
# med  eCDF diff........   0.016569 	 	  0.0097518
# max  eCDF diff........   0.033138 	 	   0.019504
#
# var ratio (Tr/Co).....    0.78317 	 	     1.1671
# T-test p-value........   0.087086 	 	    0.40033
#
#
# ***** (V335) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.19801 	 	    0.16312
# mean control..........    0.23947 	 	     0.2234
# std mean diff.........    -10.398 	 	    -16.294
#
# mean raw eQQ diff.....   0.042129 	 	   0.060284
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.02073 	 	   0.030142
# med  eCDF diff........    0.02073 	 	   0.030142
# max  eCDF diff........    0.04146 	 	   0.060284
#
# var ratio (Tr/Co).....    0.87109 	 	    0.78684
# T-test p-value........   0.091615 	 	   0.039731
#
#
# ***** (V336) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.18431 	 	    0.17642
# mean control..........    0.15521 	 	    0.19149
# std mean diff.........        7.5 	 	    -3.9485
#
# mean raw eQQ diff.....   0.028825 	 	   0.015071
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.014549 	 	  0.0075355
# med  eCDF diff........   0.014549 	 	  0.0075355
# max  eCDF diff........   0.029098 	 	   0.015071
#
# var ratio (Tr/Co).....     1.1455 	 	    0.93847
# T-test p-value........     0.1839 	 	    0.58516
#
#
# ***** (V337) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.16687 	 	    0.15426
# mean control..........   0.084257 	 	    0.13298
# std mean diff.........     22.144 	 	     5.8828
#
# mean raw eQQ diff.....    0.08204 	 	   0.021277
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.041309 	 	   0.010638
# med  eCDF diff........   0.041309 	 	   0.010638
# max  eCDF diff........   0.082617 	 	   0.021277
#
# var ratio (Tr/Co).....     1.8001 	 	     1.1315
# T-test p-value........ 9.4522e-06 	 	    0.41105
#
#
# ***** (V338) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.16065 	 	    0.11348
# mean control..........   0.011086 	 	   0.082447
# std mean diff.........     40.704 	 	     9.7698
#
# mean raw eQQ diff.....    0.14856 	 	   0.031028
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.074781 	 	   0.015514
# med  eCDF diff........   0.074781 	 	   0.015514
# max  eCDF diff........    0.14956 	 	   0.031028
#
# var ratio (Tr/Co).....     12.287 	 	     1.3298
# T-test p-value........ < 2.22e-16 	 	     0.1599
#
#
# ***** (V339) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.84433 	 	     0.8023
# mean control..........    0.74279 	 	    0.82181
# std mean diff.........     27.991 	 	    -4.8907
#
# mean raw eQQ diff.....   0.099778 	 	   0.019504
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.05077 	 	  0.0097518
# med  eCDF diff........    0.05077 	 	  0.0097518
# max  eCDF diff........    0.10154 	 	   0.019504
#
# var ratio (Tr/Co).....    0.68728 	 	     1.0831
# T-test p-value........ 3.1568e-05 	 	     0.4936
#
#
# ***** (V340) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.38107 	 	    0.26418
# mean control..........    0.17517 	 	    0.28989
# std mean diff.........     42.371 	 	    -5.8233
#
# mean raw eQQ diff.....    0.20621 	 	   0.025709
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.10295 	 	   0.012855
# med  eCDF diff........    0.10295 	 	   0.012855
# max  eCDF diff........     0.2059 	 	   0.025709
#
# var ratio (Tr/Co).....     1.6308 	 	    0.94431
# T-test p-value........ 4.4409e-16 	 	    0.44054
#
#
# ***** (V341) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.54545 	 	    0.41578
# mean control..........    0.28381 	 	    0.43617
# std mean diff.........     52.513 	 	    -4.1316
#
# mean raw eQQ diff.....    0.26164 	 	    0.02039
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.13082 	 	   0.010195
# med  eCDF diff........    0.13082 	 	   0.010195
# max  eCDF diff........    0.26164 	 	    0.02039
#
# var ratio (Tr/Co).....     1.2186 	 	    0.98772
# T-test p-value........ < 2.22e-16 	 	    0.57725
#
#
# ***** (V342) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.28643 	 	    0.18351
# mean control..........    0.15965 	 	    0.22606
# std mean diff.........     28.026 	 	    -10.979
#
# mean raw eQQ diff.....    0.12639 	 	   0.042553
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.06339 	 	   0.021277
# med  eCDF diff........    0.06339 	 	   0.021277
# max  eCDF diff........    0.12678 	 	   0.042553
#
# var ratio (Tr/Co).....      1.522 	 	     0.8564
# T-test p-value........ 8.5564e-08 	 	    0.15485
#
#
# ***** (V343) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.96513 	 	    0.92819
# mean control..........    0.89357 	 	    0.95479
# std mean diff.........     38.984 	 	    -10.288
#
# mean raw eQQ diff.....   0.070953 	 	   0.026596
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.03578 	 	   0.013298
# med  eCDF diff........    0.03578 	 	   0.013298
# max  eCDF diff........   0.071561 	 	   0.026596
#
# var ratio (Tr/Co).....    0.35352 	 	      1.544
# T-test p-value........ 8.2252e-06 	 	    0.11046
#
#
# ***** (V344) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.89913 	 	    0.82713
# mean control..........     0.7561 	 	    0.85106
# std mean diff.........     47.464 	 	    -6.3216
#
# mean raw eQQ diff.....    0.14191 	 	   0.023936
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.071515 	 	   0.011968
# med  eCDF diff........   0.071515 	 	   0.011968
# max  eCDF diff........    0.14303 	 	   0.023936
#
# var ratio (Tr/Co).....    0.49133 	 	     1.1281
# T-test p-value........ 6.9079e-10 	 	    0.36087
#
#
# ***** (V345) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.95517 	 	     0.9477
# mean control..........    0.92018 	 	    0.95479
# std mean diff.........     16.899 	 	    -3.1812
#
# mean raw eQQ diff.....   0.033259 	 	  0.0070922
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.017495 	 	  0.0035461
# med  eCDF diff........   0.017495 	 	  0.0035461
# max  eCDF diff........   0.034991 	 	  0.0070922
#
# var ratio (Tr/Co).....    0.58243 	 	     1.1483
# T-test p-value........   0.017685 	 	    0.65689
#
#
# ***** (V346) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.022416 	 	   0.042553
# mean control..........   0.068736 	 	   0.037234
# std mean diff.........    -31.271 	 	     2.6317
#
# mean raw eQQ diff.....   0.046563 	 	  0.0053191
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........    0.02316 	 	  0.0026596
# med  eCDF diff........    0.02316 	 	  0.0026596
# max  eCDF diff........    0.04632 	 	  0.0053191
#
# var ratio (Tr/Co).....      0.342 	 	     1.1365
# T-test p-value........ 0.00040331 	 	    0.70562
#
#
# ***** (V347) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.083437 	 	    0.10727
# mean control..........     0.1796 	 	    0.11968
# std mean diff.........    -34.752 	 	    -4.0054
#
# mean raw eQQ diff.....   0.095344 	 	   0.012411
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.048082 	 	  0.0062057
# med  eCDF diff........   0.048082 	 	  0.0062057
# max  eCDF diff........   0.096164 	 	   0.012411
#
# var ratio (Tr/Co).....    0.51852 	 	    0.90893
# T-test p-value........ 3.4829e-06 	 	    0.58933
#
#
# ***** (V348) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.24284 	 	    0.32092
# mean control..........     0.3459 	 	    0.30319
# std mean diff.........    -24.019 	 	      3.793
#
# mean raw eQQ diff.....    0.10421 	 	    0.01773
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.051529 	 	  0.0088652
# med  eCDF diff........   0.051529 	 	  0.0088652
# max  eCDF diff........    0.10306 	 	    0.01773
#
# var ratio (Tr/Co).....    0.81188 	 	     1.0315
# T-test p-value........  0.0001495 	 	    0.60719
#
#
# ***** (V349) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.28518 	 	     0.2961
# mean control..........    0.22616 	 	    0.25798
# std mean diff.........     13.063 	 	     8.3389
#
# mean raw eQQ diff.....    0.05765 	 	   0.038121
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029508 	 	    0.01906
# med  eCDF diff........   0.029508 	 	    0.01906
# max  eCDF diff........   0.059016 	 	   0.038121
#
# var ratio (Tr/Co).....     1.1636 	 	     1.0888
# T-test p-value........   0.020155 	 	    0.24228
#
#
# ***** (V350) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.19303 	 	    0.11968
# mean control..........    0.11308 	 	    0.14894
# std mean diff.........     20.243 	 	    -9.0011
#
# mean raw eQQ diff.....   0.079823 	 	   0.029255
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.039972 	 	   0.014628
# med  eCDF diff........   0.039972 	 	   0.014628
# max  eCDF diff........   0.079944 	 	   0.029255
#
# var ratio (Tr/Co).....     1.5516 	 	    0.83119
# T-test p-value........ 9.6168e-05 	 	     0.2435
#
#
# ***** (V351) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.16812 	 	   0.093972
# mean control..........   0.042129 	 	      0.125
# std mean diff.........     33.669 	 	     -10.62
#
# mean raw eQQ diff.....    0.12639 	 	   0.031028
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.062995 	 	   0.015514
# med  eCDF diff........   0.062995 	 	   0.015514
# max  eCDF diff........    0.12599 	 	   0.031028
#
# var ratio (Tr/Co).....     3.4624 	 	    0.77843
# T-test p-value........  1.843e-14 	 	    0.17576
#
#
# ***** (V352) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.44707 	 	    0.36702
# mean control..........    0.38803 	 	    0.45213
# std mean diff.........     11.869 	 	    -17.634
#
# mean raw eQQ diff.....    0.05765 	 	   0.085106
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.029523 	 	   0.042553
# med  eCDF diff........   0.029523 	 	   0.042553
# max  eCDF diff........   0.059047 	 	   0.085106
#
# var ratio (Tr/Co).....       1.04 	 	    0.93786
# T-test p-value........   0.041401 	 	   0.017138
#
#
# ***** (V353) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........    0.92777 	 	    0.92287
# mean control..........      0.898 	 	    0.92553
# std mean diff.........     11.492 	 	   -0.99554
#
# mean raw eQQ diff.....   0.028825 	 	  0.0026596
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.014883 	 	  0.0013298
# med  eCDF diff........   0.014883 	 	  0.0013298
# max  eCDF diff........   0.029766 	 	  0.0026596
#
# var ratio (Tr/Co).....    0.73092 	 	     1.0327
# T-test p-value........   0.079332 	 	    0.89082
#
#
# ***** (V354) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.064757 	 	   0.071809
# mean control..........   0.088692 	 	   0.069149
# std mean diff.........    -9.7196 	 	     1.0288
#
# mean raw eQQ diff.....    0.02439 	 	  0.0026596
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          1
#
# mean eCDF diff........   0.011967 	 	  0.0013298
# med  eCDF diff........   0.011967 	 	  0.0013298
# max  eCDF diff........   0.023935 	 	  0.0026596
#
# var ratio (Tr/Co).....    0.74858 	 	     1.0355
# T-test p-value........    0.13439 	 	    0.88648
#
#
# ***** (V355) out *****
#                        Before Matching 	 	 After Matching
# mean treatment........   0.007472 	 	  0.0053191
# mean control..........   0.013304 	 	  0.0053191
# std mean diff.........    -6.7677 	 	          0
#
# mean raw eQQ diff.....  0.0066519 	 	          0
# med  raw eQQ diff.....          0 	 	          0
# max  raw eQQ diff.....          1 	 	          0
#
# mean eCDF diff........  0.0029159 	 	          0
# med  eCDF diff........  0.0029159 	 	          0
# max  eCDF diff........  0.0058318 	 	          0
#
# var ratio (Tr/Co).....    0.56441 	 	          1
# T-test p-value........    0.34707 	 	          1
#
#
# Before Matching Minimum p.value: < 2.22e-16
# Variable Name(s): out out out out out out out out out out out  Number(s): 105 106 109 110 117 220 266 282 328 338 341
#
# After Matching Minimum p.value: 5.4793e-05
# Variable Name(s): out  Number(s): 31
#      bf.bal    af.bal
# [1,] 0.4084507 0.8788732
# Rosenbaum Sensitivity Test for Hodges-Lehmann Point Estimate
#      Gamma L. Bound HL Est. U. Bound HL Est.
# base     1        1.0000618         1.000062
#          2       -0.0099382         1.500100
#          3       -0.5099400         2.000100
#          4       -0.5199400         2.500100
#          5       -1.0099000         2.510100
#
# Note: Gamma is Log Odds of Differential Assignment To Treatment Due To Unobserved Factors
